# %%
stop

# %% [markdown]
# # Q-Learning - 1 - Galinha medrosa
#
# Aprendeu a desviar muito bem dos carros!
#
# No entanto, às vezes fica parando sem motivo.
#
# Por causa disso, optamos por colocar uma reward
#
# ```
# epochs = 5000
# GAMMA = 0.99
# AVAILABLE_ACTIONS = 2
# N0 = 2.5
#
# reward_policy.REWARD_IF_CROSS = 50
# reward_policy.REWARD_IF_COLISION = -1
# reward_policy.REWARD_IF_STILL = reward
# ```

# %%
aux_plots.plot_scores(scores)

# %%
aux_plots.plot_rewards(total_rewards)

# %% [markdown]
# # Q-Learning - 2 - Ótimos resultados!
#
# Não está ótima ainda, mas consegue fazer 30 pontos de forma consistente!
#
# ```
# GAMMA = 0.99
# AVAILABLE_ACTIONS = 2
# N0 = 2.5
#
# reward_policy.REWARD_IF_CROSS = 50
# reward_policy.REWARD_IF_COLISION = -1
# reward_policy.REWARD_IF_STILL = -0.1
# ```

# %%
aux_plots.plot_scores(scores)

# %%
aux_plots.plot_rewards(total_rewards)

# %% [markdown]
# # Montecarlo Approximator

# %% [markdown]
# ##  1. Importing Libraries

# %%
# %load_ext autoreload

# %autoreload 2

# %%
import sys
sys.path.append('../')  # Enable importing from `src` folder

# %%
# %matplotlib inline
from tqdm import tqdm
from collections import defaultdict
from typing import List
import pickle
import numpy as np
import time
import matplotlib.pyplot as plt
import seaborn as sns

import gym

import src.agents as agents
import src.episode as episode
import src.environment as environment
import src.aux_plots as aux_plots
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# ##  2. Auxiliary functions

# %% [markdown]
# ### 2.1 Print Result

# %%
def print_result(i, scores, total_reward, score):
    if i % 10 == 0:
        print(f"Run [{i:4}] - Total reward: {total_reward:7.2f} Mean scores: {sum(scores) / len(scores):.2f} Means Scores[:-10]: {sum(scores[-10:]) / len(scores[-10:]):5.2f} Score: {score:2} ")

# %%
RAM_mask = [
      14  # Chicken Y
    , 16  # Chicken Lane Collide
    , 108, 109, 110, 111, 112, 113, 114, 115, 116, 117  # Car X Coords
]

# %% [markdown]
# ###  2.2 Reduce State

# %%
def reduce_state(ob):
    # Doesn't matter where we were hit
    ob[16] = 1 if ob[16] != 255 else 0

    # Reduce chicken y-position
    ob[14] = ob[14] // 3

    for b in range(108, 118):
        # The chicken is in the x-posistion ~49
        if ob[b] < 20 or ob[b] > 80:
            # We don't need to represent cars far from the chicken
            ob[b] = 0
        else:
            # Reduce the cars x-positions sample space
            ob[b] = ob[b] // 3

    return ob

# %% [markdown]
# ### 2.3 Saving and Load History

# %%
def saveHistory(config,scores,total_rewards):
    base="history/"
    with open(base+"scores_"+config+".pickle", 'wb') as handle:
        pickle.dump(scores, handle, protocol=pickle.HIGHEST_PROTOCOL)
        
    with open(base+"total_rewards_"+config+".pickle", 'wb') as handle:
        pickle.dump(total_rewards, handle, protocol=pickle.HIGHEST_PROTOCOL)    
    print("Scores and Total rewards for "+config+" saved")
    
def loadHistory(fileDir):
    with open(fileDir, 'rb') as handle:
        data = pickle.load(handle)
        return data

# %% [markdown]
# ###  2.4 Reward Policy

# %%
def reward_policy(reward, ob, action):
    if reward == 1:
        reward = reward_policy.REWARD_IF_CROSS
    elif ob[16] == 1:  # Collision!
        reward = reward_policy.REWARD_IF_COLISION
    elif action != 1:  # Don't incentivate staying still
        reward = reward_policy.REWARD_IF_STILL

    return reward

# %% [markdown]
# ## 3. Running algorithms

# %% [markdown]
# ### 3.1 Setting Parameters

# %%
GAMMA = 0.99
AVAILABLE_ACTIONS = 2
N0 = 2.5

reward_policy.REWARD_IF_CROSS = 50
reward_policy.REWARD_IF_COLISION = -1
reward_policy.REWARD_IF_STILL = -0.1

# %% [markdown]
# ## 3.2 Montecarlo approximator

# %% [markdown]
# ### 3.2.1 All features + StandarScaler

# %%
def MonteCarloAprox(RAM_mask: List[int], render: bool=False,feat_type: str="all"):
    epi = episode.generate_episode(env, reduce_state=reduce_state, reward_policy=reward_policy, agent=agent, RAM_mask=RAM_mask, render=render)
    return agent.updating(epi,feat_type)

# %%
env, initial_state = environment.get_env()

# %%
agent = agents.MonteCarloAprox(gamma=GAMMA, available_actions=AVAILABLE_ACTIONS, N0=N0,nFeatures=len(RAM_mask),scaler=StandardScaler(),typeScale="all")

# %%
agent.trainScaler(env,RAM_mask,feat_type='all')

# %%
scores = []
total_rewards = []

# %%
# %%time

n_runs = 2000

for i in range(n_runs):
    render = i % 201 == 200

    score, total_reward = MonteCarloAprox(RAM_mask=RAM_mask, render=render,feat_type="all")

    scores.append(score)
    total_rewards.append(total_reward)

    print_result(i, scores, total_reward, score)
    """
    if i % 500 == 0:
      exp = serializer.Experiment(ql_agent_app, scores, total_rewards, reduce_state, reward_policy)
      exp.save_experiment(modelSavePath,'model_ql_approximator_'+str(i))
      print("Model saved!")
    """
# Out:
# Run [   0] - Total reward:  344.50 Mean scores: 11.00 Means Scores[:-10]: 11.00 Score: 11
# Run [  10] - Total reward:  398.60 Mean scores: 13.00 Means Scores[:-10]: 13.20 Score: 12
# Run [  20] - Total reward:  292.30 Mean scores: 12.67 Means Scores[:-10]: 12.30 Score: 10
# Run [  30] - Total reward:  345.30 Mean scores: 12.52 Means Scores[:-10]: 12.20 Score: 11
# Run [  40] - Total reward:  399.10 Mean scores: 12.73 Means Scores[:-10]: 13.40 Score: 12
# Run [  50] - Total reward:  572.70 Mean scores: 12.94 Means Scores[:-10]: 13.80 Score: 15
# Run [  60] - Total reward:  475.30 Mean scores: 12.93 Means Scores[:-10]: 12.90 Score: 13
# Run [  70] - Total reward:  466.10 Mean scores: 12.92 Means Scores[:-10]: 12.80 Score: 13
# Run [  80] - Total reward:  584.10 Mean scores: 13.00 Means Scores[:-10]: 13.60 Score: 15
# Run [  90] - Total reward:  451.60 Mean scores: 13.01 Means Scores[:-10]: 13.10 Score: 13
# Run [ 100] - Total reward:  422.40 Mean scores: 13.07 Means Scores[:-10]: 13.60 Score: 12
# Run [ 110] - Total reward:  475.00 Mean scores: 13.12 Means Scores[:-10]: 13.60 Score: 13
# Run [ 120] - Total reward:  413.30 Mean scores: 13.14 Means Scores[:-10]: 13.40 Score: 12
# Run [ 130] - Total reward:  456.90 Mean scores: 13.20 Means Scores[:-10]: 13.90 Score: 13
# Run [ 140] - Total reward:  575.90 Mean scores: 13.26 Means Scores[:-10]: 14.10 Score: 15
# Run [ 150] - Total reward:  695.50 Mean scores: 13.30 Means Scores[:-10]: 13.90 Score: 17
# Run [ 160] - Total reward:  295.20 Mean scores: 13.37 Means Scores[:-10]: 14.30 Score: 10
# Run [ 170] - Total reward:  474.30 Mean scores: 13.38 Means Scores[:-10]: 13.60 Score: 13
# Run [ 180] - Total reward:  463.10 Mean scores: 13.45 Means Scores[:-10]: 14.60 Score: 13
# Run [ 190] - Total reward:  529.10 Mean scores: 13.50 Means Scores[:-10]: 14.50 Score: 14
# Run [ 200] - Total reward:  588.10 Mean scores: 13.54 Means Scores[:-10]: 14.20 Score: 15
# Run [ 210] - Total reward:  351.80 Mean scores: 13.56 Means Scores[:-10]: 14.10 Score: 11
# Run [ 220] - Total reward:  700.80 Mean scores: 13.61 Means Scores[:-10]: 14.60 Score: 17
# Run [ 230] - Total reward:  419.30 Mean scores: 13.64 Means Scores[:-10]: 14.20 Score: 12
# Run [ 240] - Total reward:  535.10 Mean scores: 13.66 Means Scores[:-10]: 14.20 Score: 14
# Run [ 250] - Total reward:  473.10 Mean scores: 13.72 Means Scores[:-10]: 15.10 Score: 13
# Run [ 260] - Total reward:  532.40 Mean scores: 13.77 Means Scores[:-10]: 15.20 Score: 14
# Run [ 270] - Total reward:  603.40 Mean scores: 13.79 Means Scores[:-10]: 14.10 Score: 15
# Run [ 280] - Total reward:  646.20 Mean scores: 13.81 Means Scores[:-10]: 14.60 Score: 16
# Run [ 290] - Total reward:  693.80 Mean scores: 13.86 Means Scores[:-10]: 15.20 Score: 17
# Run [ 300] - Total reward:  654.90 Mean scores: 13.91 Means Scores[:-10]: 15.20 Score: 16
# Run [ 310] - Total reward:  591.10 Mean scores: 13.94 Means Scores[:-10]: 15.00 Score: 15
# Run [ 320] - Total reward:  424.10 Mean scores: 13.96 Means Scores[:-10]: 14.40 Score: 12
# Run [ 330] - Total reward:  601.70 Mean scores: 13.98 Means Scores[:-10]: 14.70 Score: 15
# Run [ 340] - Total reward:  538.60 Mean scores: 14.00 Means Scores[:-10]: 14.60 Score: 14
# Run [ 350] - Total reward:  628.30 Mean scores: 14.01 Means Scores[:-10]: 14.50 Score: 16
# Run [ 360] - Total reward:  539.60 Mean scores: 14.04 Means Scores[:-10]: 15.10 Score: 14
# Run [ 370] - Total reward:  593.90 Mean scores: 14.06 Means Scores[:-10]: 14.80 Score: 15
# Run [ 380] - Total reward:  645.20 Mean scores: 14.08 Means Scores[:-10]: 14.60 Score: 16
# Run [ 390] - Total reward:  603.90 Mean scores: 14.10 Means Scores[:-10]: 14.90 Score: 15
# Run [ 400] - Total reward:  646.20 Mean scores: 14.11 Means Scores[:-10]: 14.80 Score: 16
# Run [ 410] - Total reward:  654.40 Mean scores: 14.14 Means Scores[:-10]: 15.10 Score: 16
# Run [ 420] - Total reward:  594.70 Mean scores: 14.16 Means Scores[:-10]: 15.10 Score: 15
# Run [ 430] - Total reward:  544.90 Mean scores: 14.18 Means Scores[:-10]: 15.00 Score: 14
# Run [ 440] - Total reward:  701.30 Mean scores: 14.21 Means Scores[:-10]: 15.50 Score: 17
# Run [ 450] - Total reward:  585.00 Mean scores: 14.23 Means Scores[:-10]: 14.90 Score: 15
# Run [ 460] - Total reward:  631.60 Mean scores: 14.25 Means Scores[:-10]: 15.30 Score: 16
# Run [ 470] - Total reward:  649.60 Mean scores: 14.28 Means Scores[:-10]: 15.50 Score: 16
# Run [ 480] - Total reward:  476.90 Mean scores: 14.27 Means Scores[:-10]: 13.90 Score: 13
# Run [ 490] - Total reward:  600.60 Mean scores: 14.30 Means Scores[:-10]: 15.60 Score: 15
# Run [ 500] - Total reward:  476.80 Mean scores: 14.31 Means Scores[:-10]: 15.10 Score: 13
# Run [ 510] - Total reward:  471.60 Mean scores: 14.32 Means Scores[:-10]: 14.90 Score: 13
# Run [ 520] - Total reward:  657.40 Mean scores: 14.34 Means Scores[:-10]: 15.30 Score: 16
# Run [ 530] - Total reward:  590.10 Mean scores: 14.36 Means Scores[:-10]: 15.50 Score: 15
# Run [ 540] - Total reward:  592.20 Mean scores: 14.38 Means Scores[:-10]: 15.10 Score: 15
# Run [ 550] - Total reward:  643.20 Mean scores: 14.39 Means Scores[:-10]: 15.10 Score: 16
# Run [ 560] - Total reward:  545.80 Mean scores: 14.40 Means Scores[:-10]: 15.00 Score: 14
# Run [ 570] - Total reward:  586.90 Mean scores: 14.41 Means Scores[:-10]: 14.90 Score: 15
# Run [ 580] - Total reward:  598.40 Mean scores: 14.43 Means Scores[:-10]: 15.60 Score: 15
# Run [ 590] - Total reward:  652.00 Mean scores: 14.44 Means Scores[:-10]: 15.00 Score: 16
# Run [ 600] - Total reward:  537.10 Mean scores: 14.46 Means Scores[:-10]: 15.50 Score: 14
# Run [ 610] - Total reward:  766.30 Mean scores: 14.49 Means Scores[:-10]: 16.40 Score: 18
# Run [ 620] - Total reward:  652.40 Mean scores: 14.51 Means Scores[:-10]: 15.70 Score: 16
# Run [ 630] - Total reward:  706.10 Mean scores: 14.53 Means Scores[:-10]: 15.70 Score: 17
# Run [ 640] - Total reward:  645.00 Mean scores: 14.54 Means Scores[:-10]: 15.20 Score: 16
# Run [ 650] - Total reward:  531.00 Mean scores: 14.54 Means Scores[:-10]: 14.90 Score: 14
# Run [ 660] - Total reward:  648.10 Mean scores: 14.56 Means Scores[:-10]: 15.40 Score: 16
# Run [ 670] - Total reward:  592.00 Mean scores: 14.57 Means Scores[:-10]: 15.60 Score: 15
# Run [ 680] - Total reward:  539.00 Mean scores: 14.58 Means Scores[:-10]: 15.20 Score: 14
# Run [ 690] - Total reward:  702.20 Mean scores: 14.59 Means Scores[:-10]: 15.30 Score: 17
# Run [ 700] - Total reward:  540.20 Mean scores: 14.61 Means Scores[:-10]: 16.00 Score: 14
# Run [ 710] - Total reward:  590.50 Mean scores: 14.62 Means Scores[:-10]: 15.50 Score: 15
# Run [ 720] - Total reward:  651.50 Mean scores: 14.64 Means Scores[:-10]: 16.10 Score: 16
# Run [ 730] - Total reward:  535.20 Mean scores: 14.65 Means Scores[:-10]: 15.20 Score: 14
# Run [ 740] - Total reward:  757.30 Mean scores: 14.67 Means Scores[:-10]: 15.80 Score: 18
# Run [ 750] - Total reward:  549.20 Mean scores: 14.68 Means Scores[:-10]: 15.40 Score: 14
# Run [ 760] - Total reward:  599.60 Mean scores: 14.69 Means Scores[:-10]: 15.30 Score: 15
# Run [ 770] - Total reward:  649.10 Mean scores: 14.70 Means Scores[:-10]: 15.90 Score: 16
# Run [ 780] - Total reward:  705.70 Mean scores: 14.72 Means Scores[:-10]: 15.80 Score: 17
# Run [ 790] - Total reward:  546.20 Mean scores: 14.72 Means Scores[:-10]: 14.90 Score: 14
# Run [ 800] - Total reward:  482.30 Mean scores: 14.73 Means Scores[:-10]: 15.60 Score: 13
# Run [ 810] - Total reward:  597.30 Mean scores: 14.74 Means Scores[:-10]: 15.60 Score: 15
# Run [ 820] - Total reward:  532.30 Mean scores: 14.75 Means Scores[:-10]: 15.30 Score: 14
# Run [ 830] - Total reward:  640.00 Mean scores: 14.77 Means Scores[:-10]: 16.30 Score: 16
# Run [ 840] - Total reward:  760.20 Mean scores: 14.78 Means Scores[:-10]: 16.30 Score: 18
# Run [ 850] - Total reward:  711.90 Mean scores: 14.80 Means Scores[:-10]: 16.30 Score: 17
# Run [ 860] - Total reward:  587.50 Mean scores: 14.81 Means Scores[:-10]: 15.20 Score: 15
# Run [ 870] - Total reward:  705.50 Mean scores: 14.81 Means Scores[:-10]: 15.40 Score: 17
# Run [ 880] - Total reward:  760.20 Mean scores: 14.82 Means Scores[:-10]: 15.50 Score: 18
# Run [ 890] - Total reward:  709.90 Mean scores: 14.84 Means Scores[:-10]: 16.10 Score: 17
# Run [ 900] - Total reward:  521.40 Mean scores: 14.84 Means Scores[:-10]: 15.30 Score: 14
# Run [ 910] - Total reward:  475.20 Mean scores: 14.85 Means Scores[:-10]: 15.60 Score: 13
# Run [ 920] - Total reward:  641.70 Mean scores: 14.85 Means Scores[:-10]: 15.40 Score: 16
# Run [ 930] - Total reward:  647.00 Mean scores: 14.85 Means Scores[:-10]: 14.80 Score: 16
# Run [ 940] - Total reward:  536.00 Mean scores: 14.85 Means Scores[:-10]: 14.50 Score: 14
# Run [ 950] - Total reward:  762.50 Mean scores: 14.86 Means Scores[:-10]: 16.10 Score: 18
# Run [ 960] - Total reward:  639.40 Mean scores: 14.88 Means Scores[:-10]: 16.00 Score: 16
# Run [ 970] - Total reward:  545.00 Mean scores: 14.87 Means Scores[:-10]: 14.60 Score: 14
# Run [ 980] - Total reward:  644.00 Mean scores: 14.88 Means Scores[:-10]: 15.70 Score: 16
# Run [ 990] - Total reward:  533.80 Mean scores: 14.88 Means Scores[:-10]: 15.00 Score: 14
# Run [1000] - Total reward:  697.40 Mean scores: 14.89 Means Scores[:-10]: 16.10 Score: 17
# Run [1010] - Total reward:  661.70 Mean scores: 14.90 Means Scores[:-10]: 15.80 Score: 16
# Run [1020] - Total reward:  760.40 Mean scores: 14.91 Means Scores[:-10]: 16.00 Score: 18
# Run [1030] - Total reward:  702.00 Mean scores: 14.93 Means Scores[:-10]: 16.20 Score: 17
# Run [1040] - Total reward:  601.90 Mean scores: 14.93 Means Scores[:-10]: 15.00 Score: 15
# Run [1050] - Total reward:  594.60 Mean scores: 14.93 Means Scores[:-10]: 15.20 Score: 15
# Run [1060] - Total reward:  658.30 Mean scores: 14.94 Means Scores[:-10]: 15.60 Score: 16
# Run [1070] - Total reward:  648.50 Mean scores: 14.94 Means Scores[:-10]: 14.90 Score: 16
# Run [1080] - Total reward:  648.10 Mean scores: 14.94 Means Scores[:-10]: 15.30 Score: 16
# Run [1090] - Total reward:  486.30 Mean scores: 14.94 Means Scores[:-10]: 14.80 Score: 13
# Run [1100] - Total reward:  593.90 Mean scores: 14.94 Means Scores[:-10]: 15.60 Score: 15
# Run [1110] - Total reward:  534.30 Mean scores: 14.95 Means Scores[:-10]: 15.60 Score: 14
# Run [1120] - Total reward:  693.70 Mean scores: 14.96 Means Scores[:-10]: 15.90 Score: 17
# Run [1130] - Total reward:  589.10 Mean scores: 14.96 Means Scores[:-10]: 15.20 Score: 15
# Run [1140] - Total reward:  657.30 Mean scores: 14.96 Means Scores[:-10]: 14.90 Score: 16
# Run [1150] - Total reward:  813.60 Mean scores: 14.97 Means Scores[:-10]: 16.20 Score: 19
# Run [1160] - Total reward:  707.50 Mean scores: 14.98 Means Scores[:-10]: 15.90 Score: 17
# Run [1170] - Total reward:  582.30 Mean scores: 14.98 Means Scores[:-10]: 15.70 Score: 15
# Run [1180] - Total reward:  708.90 Mean scores: 14.99 Means Scores[:-10]: 15.90 Score: 17
# Run [1190] - Total reward:  530.70 Mean scores: 15.00 Means Scores[:-10]: 15.90 Score: 14
# Run [1200] - Total reward:  641.90 Mean scores: 15.00 Means Scores[:-10]: 15.60 Score: 16
# Run [1210] - Total reward:  641.90 Mean scores: 15.01 Means Scores[:-10]: 15.70 Score: 16
# Run [1220] - Total reward:  586.70 Mean scores: 15.02 Means Scores[:-10]: 16.00 Score: 15
# Run [1230] - Total reward:  601.90 Mean scores: 15.03 Means Scores[:-10]: 16.30 Score: 15
# Run [1240] - Total reward:  544.40 Mean scores: 15.03 Means Scores[:-10]: 15.50 Score: 14
# Run [1250] - Total reward:  588.00 Mean scores: 15.04 Means Scores[:-10]: 15.70 Score: 15
# Run [1260] - Total reward:  496.50 Mean scores: 15.04 Means Scores[:-10]: 15.30 Score: 13
# Run [1270] - Total reward:  755.40 Mean scores: 15.05 Means Scores[:-10]: 16.00 Score: 18
# Run [1280] - Total reward:  758.60 Mean scores: 15.06 Means Scores[:-10]: 16.60 Score: 18
# Run [1290] - Total reward:  637.80 Mean scores: 15.07 Means Scores[:-10]: 16.10 Score: 16
# Run [1300] - Total reward:  654.10 Mean scores: 15.07 Means Scores[:-10]: 15.70 Score: 16
# Run [1310] - Total reward:  871.00 Mean scores: 15.07 Means Scores[:-10]: 14.80 Score: 20
# Run [1320] - Total reward:  661.10 Mean scores: 15.08 Means Scores[:-10]: 15.90 Score: 16
# Run [1330] - Total reward:  540.40 Mean scores: 15.08 Means Scores[:-10]: 16.10 Score: 14
# Run [1340] - Total reward:  591.80 Mean scores: 15.09 Means Scores[:-10]: 15.30 Score: 15
# Run [1350] - Total reward:  708.80 Mean scores: 15.09 Means Scores[:-10]: 15.80 Score: 17
# Run [1360] - Total reward:  580.30 Mean scores: 15.10 Means Scores[:-10]: 16.20 Score: 15
# Run [1370] - Total reward:  547.80 Mean scores: 15.10 Means Scores[:-10]: 15.20 Score: 14
# Run [1380] - Total reward:  599.10 Mean scores: 15.10 Means Scores[:-10]: 15.50 Score: 15
# Run [1390] - Total reward:  643.10 Mean scores: 15.11 Means Scores[:-10]: 15.50 Score: 16
# Run [1400] - Total reward:  544.40 Mean scores: 15.10 Means Scores[:-10]: 14.90 Score: 14
# Run [1410] - Total reward:  601.00 Mean scores: 15.11 Means Scores[:-10]: 15.90 Score: 15
# Run [1420] - Total reward:  596.20 Mean scores: 15.11 Means Scores[:-10]: 15.40 Score: 15
# Run [1430] - Total reward:  655.40 Mean scores: 15.12 Means Scores[:-10]: 15.80 Score: 16
# Run [1440] - Total reward:  598.90 Mean scores: 15.12 Means Scores[:-10]: 15.40 Score: 15
# Run [1450] - Total reward:  598.00 Mean scores: 15.13 Means Scores[:-10]: 16.00 Score: 15
# Run [1460] - Total reward:  651.50 Mean scores: 15.13 Means Scores[:-10]: 16.10 Score: 16
# Run [1470] - Total reward:  696.60 Mean scores: 15.13 Means Scores[:-10]: 15.40 Score: 17
# Run [1480] - Total reward:  542.80 Mean scores: 15.14 Means Scores[:-10]: 16.00 Score: 14
# Run [1490] - Total reward:  529.90 Mean scores: 15.14 Means Scores[:-10]: 15.60 Score: 14
# Run [1500] - Total reward:  754.80 Mean scores: 15.15 Means Scores[:-10]: 15.90 Score: 18
# Run [1510] - Total reward:  607.40 Mean scores: 15.15 Means Scores[:-10]: 15.10 Score: 15
# Run [1520] - Total reward:  595.60 Mean scores: 15.15 Means Scores[:-10]: 15.40 Score: 15
# Run [1530] - Total reward:  747.90 Mean scores: 15.15 Means Scores[:-10]: 15.50 Score: 18
# Run [1540] - Total reward:  656.30 Mean scores: 15.16 Means Scores[:-10]: 15.80 Score: 16
# Run [1550] - Total reward:  421.50 Mean scores: 15.16 Means Scores[:-10]: 16.00 Score: 12
# Run [1560] - Total reward:  531.50 Mean scores: 15.17 Means Scores[:-10]: 16.50 Score: 14
# Run [1570] - Total reward:  704.30 Mean scores: 15.17 Means Scores[:-10]: 15.50 Score: 17
# Run [1580] - Total reward:  593.50 Mean scores: 15.17 Means Scores[:-10]: 14.60 Score: 15
# Run [1590] - Total reward:  536.90 Mean scores: 15.17 Means Scores[:-10]: 16.00 Score: 14
# Run [1600] - Total reward:  701.50 Mean scores: 15.18 Means Scores[:-10]: 16.10 Score: 17
# Run [1610] - Total reward:  598.60 Mean scores: 15.18 Means Scores[:-10]: 15.50 Score: 15
# Run [1620] - Total reward:  595.30 Mean scores: 15.18 Means Scores[:-10]: 15.30 Score: 15
# Run [1630] - Total reward:  642.90 Mean scores: 15.18 Means Scores[:-10]: 15.60 Score: 16
# Run [1640] - Total reward:  532.60 Mean scores: 15.19 Means Scores[:-10]: 16.00 Score: 14
# Run [1650] - Total reward:  487.30 Mean scores: 15.19 Means Scores[:-10]: 15.70 Score: 13
# Run [1660] - Total reward:  692.90 Mean scores: 15.20 Means Scores[:-10]: 16.10 Score: 17
# Run [1670] - Total reward:  704.50 Mean scores: 15.20 Means Scores[:-10]: 16.00 Score: 17
# Run [1680] - Total reward:  580.70 Mean scores: 15.21 Means Scores[:-10]: 16.10 Score: 15
# Run [1690] - Total reward:  696.70 Mean scores: 15.21 Means Scores[:-10]: 16.00 Score: 17
# Run [1700] - Total reward:  577.50 Mean scores: 15.21 Means Scores[:-10]: 15.50 Score: 15
# Run [1710] - Total reward:  703.70 Mean scores: 15.22 Means Scores[:-10]: 15.30 Score: 17
# Run [1720] - Total reward:  598.50 Mean scores: 15.22 Means Scores[:-10]: 15.50 Score: 15
# Run [1730] - Total reward:  481.60 Mean scores: 15.22 Means Scores[:-10]: 15.10 Score: 13
# Run [1740] - Total reward:  638.20 Mean scores: 15.21 Means Scores[:-10]: 14.90 Score: 16
# Run [1750] - Total reward:  762.60 Mean scores: 15.22 Means Scores[:-10]: 16.50 Score: 18
# Run [1760] - Total reward:  541.30 Mean scores: 15.22 Means Scores[:-10]: 15.70 Score: 14
# Run [1770] - Total reward:  759.60 Mean scores: 15.23 Means Scores[:-10]: 16.30 Score: 18
# Run [1780] - Total reward:  631.50 Mean scores: 15.23 Means Scores[:-10]: 15.20 Score: 16
# Run [1790] - Total reward:  591.30 Mean scores: 15.23 Means Scores[:-10]: 15.40 Score: 15
# Run [1800] - Total reward:  656.50 Mean scores: 15.23 Means Scores[:-10]: 15.70 Score: 16
# Run [1810] - Total reward:  596.70 Mean scores: 15.24 Means Scores[:-10]: 15.80 Score: 15
# Run [1820] - Total reward:  655.30 Mean scores: 15.24 Means Scores[:-10]: 15.30 Score: 16
# Run [1830] - Total reward:  656.30 Mean scores: 15.24 Means Scores[:-10]: 16.00 Score: 16
# Run [1840] - Total reward:  651.00 Mean scores: 15.24 Means Scores[:-10]: 15.30 Score: 16
# Run [1850] - Total reward:  705.90 Mean scores: 15.24 Means Scores[:-10]: 15.50 Score: 17
# Run [1860] - Total reward:  713.90 Mean scores: 15.25 Means Scores[:-10]: 16.80 Score: 17
# Run [1870] - Total reward:  582.10 Mean scores: 15.26 Means Scores[:-10]: 16.60 Score: 15
# Run [1880] - Total reward:  656.10 Mean scores: 15.26 Means Scores[:-10]: 15.20 Score: 16
# Run [1890] - Total reward:  651.80 Mean scores: 15.26 Means Scores[:-10]: 15.50 Score: 16
# Run [1900] - Total reward:  704.10 Mean scores: 15.26 Means Scores[:-10]: 15.40 Score: 17
# Run [1910] - Total reward:  642.10 Mean scores: 15.26 Means Scores[:-10]: 15.80 Score: 16
# Run [1920] - Total reward:  482.60 Mean scores: 15.26 Means Scores[:-10]: 15.50 Score: 13
# Run [1930] - Total reward:  704.80 Mean scores: 15.27 Means Scores[:-10]: 15.60 Score: 17
# Run [1940] - Total reward:  769.00 Mean scores: 15.27 Means Scores[:-10]: 15.60 Score: 18
# Run [1950] - Total reward:  542.20 Mean scores: 15.27 Means Scores[:-10]: 16.20 Score: 14
# Run [1960] - Total reward:  488.90 Mean scores: 15.27 Means Scores[:-10]: 15.20 Score: 13
# Run [1970] - Total reward:  664.20 Mean scores: 15.27 Means Scores[:-10]: 15.50 Score: 16
# Run [1980] - Total reward:  660.60 Mean scores: 15.28 Means Scores[:-10]: 16.50 Score: 16
# Run [1990] - Total reward:  697.60 Mean scores: 15.28 Means Scores[:-10]: 15.60 Score: 17
# CPU times: user 1h 34min 14s, sys: 3.53 s, total: 1h 34min 18s
# Wall time: 1h 36min 31s

# %%
aux_plots.plot_scores(scores)

# %%
aux_plots.plot_rewards(total_rewards)

# %%
saveHistory("MontecarloAproximatorAllFeaturesBias2000",scores,total_rewards)
# Out:
# Scores and Total rewards for MontecarloAproximatorAllFeaturesBias2000 saved

# %%
import sys
sys.path.append('/content/FreewayGame/leonardo/')
# %matplotlib inline
from collections import defaultdict
from typing import List

import numpy as np
import time
import matplotlib.pyplot as plt
import seaborn as sns

import gym

import src.agents as agents
import src.episode as episode
import src.environment as environment
import src.aux_plots as aux_plots

# %%
def print_result(i, scores, total_reward, score):
    if i % 10 == 0:
        print(f"Run [{i:4}] - Total reward: {total_reward:7.2f} Mean scores: {sum(scores) / len(scores):.2f} Means Scores[:-10]: {sum(scores[-10:]) / len(scores[-10:]):5.2f} Score: {score:2} ")

# %%
RAM_mask = [
      14  # Chicken Y
    , 16  # Chicken Lane Collide
    , 108, 109, 110, 111, 112, 113, 114, 115, 116, 117  # Car X Coords
]

# %%
def reduce_state(ob):
    # Doesn't matter where we were hit
    ob[16] = 1 if ob[16] != 255 else 0

    # Reduce chicken y-position
    ob[14] = ob[14] // 3

    for b in range(108, 118):
        # The chicken is in the x-posistion ~49
        if ob[b] < 20 or ob[b] > 80:
            # We don't need to represent cars far from the chicken
            ob[b] = 0
        else:
            # Reduce the cars x-positions sample space
            ob[b] = ob[b] // 3

    return ob
    
def reward_policy(reward, ob, action):
    if reward == 1:
        reward = reward_policy.REWARD_IF_CROSS
    elif ob[16] == 1:  # Collision!
        reward = reward_policy.REWARD_IF_COLISION
    elif action != 1:  # Don't incentivate staying still
        reward = reward_policy.REWARD_IF_STILL

    return reward

def train(agent, env, name, n_runs=5000, n_render=500, n_print=10):
    scores = []
    total_rewards = []
    for i in range(n_runs):
        render = i % n_render == (n_render-1)

        E = defaultdict(lambda: np.zeros(2))

        game_over = False
        state = env.reset()
        state = reduce_state(state)[RAM_mask].data.tobytes()  # Select useful bytes
        action = agent.act(state)

        score = 0
        total_reward = 0

        while not game_over:
            if render:
                time.sleep(0.005)
                env.render()

            old_state = state
            old_action = action
            ob, reward, game_over, _ = env.step(action)

            ob = reduce_state(ob)
            reward = reward_policy(reward, ob, action)

            total_reward += reward

            if reward == reward_policy.REWARD_IF_CROSS:
                score += 1

            state = ob[RAM_mask].data.tobytes()

            action = agent.act(state)  # Next action

            E[old_state][old_action] += 1

            agent.update(old_s=old_state, new_s=state, old_a=old_action, new_a=action, reward=reward, E=i+1)

        scores.append(score)
        total_rewards.append(total_reward)
        
        if i%500 == 499:
        
            exp = serializer.Experiment(agent, scores, total_rewards, reduce_state, reward_policy)
            exp.save_experiment(name)

        if i % n_print == 0:
            print(f"Run [{i:4}] - Total reward: {total_reward:7.2f} Mean scores: {sum(scores) / len(scores):.2f} Means Scores[:-10]: {sum(scores[-10:]) / len(scores[-10:]):5.2f} Score: {score:2} ")
    return scores, total_rewards

# %%
def run_adam_experiment_eng1(n_runs=5000, AVAILABLE_ACTIONS = 2, GAMMA = 0.99, N0 = 2.5, ALPHA = 0.001,
                        LAMB = 0.0001, REWARD_IF_CROSS=500, REWARD_IF_COLISION=-10, REWARD_IF_STILL=-1):

    env, initial_state = environment.get_env()
    
    reward_policy.REWARD_IF_CROSS = REWARD_IF_CROSS
    reward_policy.REWARD_IF_COLISION = REWARD_IF_COLISION
    reward_policy.REWARD_IF_STILL = REWARD_IF_STILL

    agent = agents.SarsaLFAADAM(gamma=GAMMA, state_size=len(RAM_mask), available_actions=AVAILABLE_ACTIONS, N0=N0, alpha=ALPHA, lamb=LAMB, feature_set='eng1')
    agent.trainScaler(env, RAM_mask)

    
    scores, total_rewards = train(agent, env, n_runs=n_runs, n_render=500, n_print=10)
    aux_plots.plot_scores(scores)
    aux_plots.plot_rewards(total_rewards)

# %%
# %%time
run_adam_experiment_eng1()
# Out:
# Run [   0] - Total reward: 4640.00 Mean scores: 13.00 Means Scores[:-10]: 13.00 Score: 13
# Run [  10] - Total reward: 4849.00 Mean scores: 12.91 Means Scores[:-10]: 12.90 Score: 13
# Run [  20] - Total reward: 4152.00 Mean scores: 12.57 Means Scores[:-10]: 12.20 Score: 12
# Run [  30] - Total reward: 7466.00 Mean scores: 13.39 Means Scores[:-10]: 15.10 Score: 18
# Run [  40] - Total reward: 5289.00 Mean scores: 14.02 Means Scores[:-10]: 16.00 Score: 14
# Run [  50] - Total reward: 6423.00 Mean scores: 14.55 Means Scores[:-10]: 16.70 Score: 16
# Run [  60] - Total reward: 7519.00 Mean scores: 15.02 Means Scores[:-10]: 17.40 Score: 18
# Run [  70] - Total reward: 7655.00 Mean scores: 15.35 Means Scores[:-10]: 17.40 Score: 18
# Run [  80] - Total reward: 7110.00 Mean scores: 15.64 Means Scores[:-10]: 17.70 Score: 17
# Run [  90] - Total reward: 5406.00 Mean scores: 15.80 Means Scores[:-10]: 17.10 Score: 14
# Run [ 100] - Total reward: 7213.00 Mean scores: 15.98 Means Scores[:-10]: 17.60 Score: 17
# Run [ 110] - Total reward: 8750.00 Mean scores: 16.17 Means Scores[:-10]: 18.10 Score: 20
# Run [ 120] - Total reward: 8258.00 Mean scores: 16.38 Means Scores[:-10]: 18.70 Score: 19
# Run [ 130] - Total reward: 8865.00 Mean scores: 16.60 Means Scores[:-10]: 19.20 Score: 20
# Run [ 140] - Total reward: 8253.00 Mean scores: 16.77 Means Scores[:-10]: 19.10 Score: 19
# Run [ 150] - Total reward: 8859.00 Mean scores: 16.89 Means Scores[:-10]: 18.50 Score: 20
# Run [ 160] - Total reward: 7778.00 Mean scores: 16.97 Means Scores[:-10]: 18.20 Score: 18
# Run [ 170] - Total reward: 8907.00 Mean scores: 17.08 Means Scores[:-10]: 18.80 Score: 20
# Run [ 180] - Total reward: 8877.00 Mean scores: 17.20 Means Scores[:-10]: 19.30 Score: 20
# Run [ 190] - Total reward: 7886.00 Mean scores: 17.28 Means Scores[:-10]: 18.80 Score: 18
# Run [ 200] - Total reward: 7817.00 Mean scores: 17.35 Means Scores[:-10]: 18.70 Score: 18
# Run [ 210] - Total reward: 7778.00 Mean scores: 17.44 Means Scores[:-10]: 19.20 Score: 18
# Run [ 220] - Total reward: 9000.00 Mean scores: 17.52 Means Scores[:-10]: 19.20 Score: 20
# Run [ 230] - Total reward: 8838.00 Mean scores: 17.59 Means Scores[:-10]: 19.10 Score: 20
# Run [ 240] - Total reward: 8416.00 Mean scores: 17.67 Means Scores[:-10]: 19.50 Score: 19
# Run [ 250] - Total reward: 9675.00 Mean scores: 17.74 Means Scores[:-10]: 19.40 Score: 21
# Run [ 260] - Total reward: 8365.00 Mean scores: 17.82 Means Scores[:-10]: 19.90 Score: 19
# Run [ 270] - Total reward: 7368.00 Mean scores: 17.87 Means Scores[:-10]: 19.30 Score: 17
# Run [ 280] - Total reward: 8499.00 Mean scores: 17.92 Means Scores[:-10]: 19.20 Score: 19
# Run [ 290] - Total reward: 8961.00 Mean scores: 18.00 Means Scores[:-10]: 20.10 Score: 20
# Run [ 300] - Total reward: 8555.00 Mean scores: 18.03 Means Scores[:-10]: 19.00 Score: 19
# Run [ 310] - Total reward: 8354.00 Mean scores: 18.09 Means Scores[:-10]: 19.90 Score: 19
# Run [ 320] - Total reward: 9970.00 Mean scores: 18.17 Means Scores[:-10]: 20.60 Score: 22
# Run [ 330] - Total reward: 8906.00 Mean scores: 18.25 Means Scores[:-10]: 21.00 Score: 20
# Run [ 340] - Total reward: 9490.00 Mean scores: 18.30 Means Scores[:-10]: 19.80 Score: 21
# Run [ 350] - Total reward: 8393.00 Mean scores: 18.36 Means Scores[:-10]: 20.30 Score: 19
# Run [ 360] - Total reward: 10009.00 Mean scores: 18.43 Means Scores[:-10]: 21.10 Score: 22
# Run [ 370] - Total reward: 8430.00 Mean scores: 18.51 Means Scores[:-10]: 21.20 Score: 19
# Run [ 380] - Total reward: 9003.00 Mean scores: 18.58 Means Scores[:-10]: 21.20 Score: 20
# Run [ 390] - Total reward: 9434.00 Mean scores: 18.65 Means Scores[:-10]: 21.30 Score: 21
# Run [ 400] - Total reward: 7881.00 Mean scores: 18.70 Means Scores[:-10]: 20.80 Score: 18
# Run [ 410] - Total reward: 8974.00 Mean scores: 18.75 Means Scores[:-10]: 20.80 Score: 20
# Run [ 420] - Total reward: 9610.00 Mean scores: 18.79 Means Scores[:-10]: 20.20 Score: 21
# Run [ 430] - Total reward: 10096.00 Mean scores: 18.84 Means Scores[:-10]: 21.10 Score: 22
# Run [ 440] - Total reward: 10179.00 Mean scores: 18.90 Means Scores[:-10]: 21.50 Score: 22
# Run [ 450] - Total reward: 9592.00 Mean scores: 18.96 Means Scores[:-10]: 21.50 Score: 21
# Run [ 460] - Total reward: 9638.00 Mean scores: 19.00 Means Scores[:-10]: 21.00 Score: 21
# Run [ 470] - Total reward: 10609.00 Mean scores: 19.06 Means Scores[:-10]: 21.60 Score: 23
# Run [ 480] - Total reward: 10179.00 Mean scores: 19.11 Means Scores[:-10]: 21.80 Score: 22
# Run [ 490] - Total reward: 10090.00 Mean scores: 19.16 Means Scores[:-10]: 21.60 Score: 22
# Run [ 500] - Total reward: 9594.00 Mean scores: 19.22 Means Scores[:-10]: 21.80 Score: 21
# Run [ 510] - Total reward: 9662.00 Mean scores: 19.27 Means Scores[:-10]: 21.70 Score: 21
# Run [ 520] - Total reward: 10694.00 Mean scores: 19.32 Means Scores[:-10]: 22.00 Score: 23
# Run [ 530] - Total reward: 11212.00 Mean scores: 19.38 Means Scores[:-10]: 22.50 Score: 24
# Run [ 540] - Total reward: 10746.00 Mean scores: 19.43 Means Scores[:-10]: 22.00 Score: 23
# Run [ 550] - Total reward: 10120.00 Mean scores: 19.48 Means Scores[:-10]: 22.10 Score: 22
# Run [ 560] - Total reward: 9755.00 Mean scores: 19.51 Means Scores[:-10]: 21.40 Score: 21
# Run [ 570] - Total reward: 10090.00 Mean scores: 19.55 Means Scores[:-10]: 21.70 Score: 22
# Run [ 580] - Total reward: 10779.00 Mean scores: 19.60 Means Scores[:-10]: 22.40 Score: 23
# Run [ 590] - Total reward: 9178.00 Mean scores: 19.62 Means Scores[:-10]: 21.00 Score: 20
# Run [ 600] - Total reward: 9118.00 Mean scores: 19.66 Means Scores[:-10]: 21.90 Score: 20
# Run [ 610] - Total reward: 10131.00 Mean scores: 19.70 Means Scores[:-10]: 22.10 Score: 22
# Run [ 620] - Total reward: 10605.00 Mean scores: 19.73 Means Scores[:-10]: 21.80 Score: 23
# Run [ 630] - Total reward: 10150.00 Mean scores: 19.77 Means Scores[:-10]: 22.30 Score: 22
# Run [ 640] - Total reward: 10784.00 Mean scores: 19.81 Means Scores[:-10]: 22.10 Score: 23
# Run [ 650] - Total reward: 10726.00 Mean scores: 19.85 Means Scores[:-10]: 22.30 Score: 23
# Run [ 660] - Total reward: 9820.00 Mean scores: 19.88 Means Scores[:-10]: 21.90 Score: 21
# Run [ 670] - Total reward: 11322.00 Mean scores: 19.91 Means Scores[:-10]: 21.90 Score: 24
# Run [ 680] - Total reward: 11340.00 Mean scores: 19.95 Means Scores[:-10]: 22.60 Score: 24
# Run [ 690] - Total reward: 10612.00 Mean scores: 19.98 Means Scores[:-10]: 21.90 Score: 23
# Run [ 700] - Total reward: 11808.00 Mean scores: 20.02 Means Scores[:-10]: 22.90 Score: 25
# Run [ 710] - Total reward: 11341.00 Mean scores: 20.05 Means Scores[:-10]: 22.40 Score: 24
# Run [ 720] - Total reward: 11234.00 Mean scores: 20.09 Means Scores[:-10]: 22.60 Score: 24
# Run [ 730] - Total reward: 10139.00 Mean scores: 20.11 Means Scores[:-10]: 22.10 Score: 22
# Run [ 740] - Total reward: 10226.00 Mean scores: 20.15 Means Scores[:-10]: 22.80 Score: 22
# Run [ 750] - Total reward: 10282.00 Mean scores: 20.19 Means Scores[:-10]: 22.90 Score: 22
# Run [ 760] - Total reward: 10660.00 Mean scores: 20.22 Means Scores[:-10]: 22.60 Score: 23
# Run [ 770] - Total reward: 9660.00 Mean scores: 20.25 Means Scores[:-10]: 22.90 Score: 21
# Run [ 780] - Total reward: 10739.00 Mean scores: 20.28 Means Scores[:-10]: 22.60 Score: 23
# Run [ 790] - Total reward: 11228.00 Mean scores: 20.31 Means Scores[:-10]: 22.60 Score: 24
# Run [ 800] - Total reward: 10140.00 Mean scores: 20.34 Means Scores[:-10]: 22.40 Score: 22
# Run [ 810] - Total reward: 10789.00 Mean scores: 20.37 Means Scores[:-10]: 22.90 Score: 23
# Run [ 820] - Total reward: 10201.00 Mean scores: 20.40 Means Scores[:-10]: 22.70 Score: 22
# Run [ 830] - Total reward: 11310.00 Mean scores: 20.43 Means Scores[:-10]: 22.90 Score: 24
# Run [ 840] - Total reward: 11314.00 Mean scores: 20.46 Means Scores[:-10]: 22.80 Score: 24
# Run [ 850] - Total reward: 11414.00 Mean scores: 20.49 Means Scores[:-10]: 23.00 Score: 24
# Run [ 860] - Total reward: 10342.00 Mean scores: 20.52 Means Scores[:-10]: 22.90 Score: 22
# Run [ 870] - Total reward: 10245.00 Mean scores: 20.54 Means Scores[:-10]: 22.90 Score: 22
# Run [ 880] - Total reward: 10701.00 Mean scores: 20.57 Means Scores[:-10]: 22.50 Score: 23
# Run [ 890] - Total reward: 9120.00 Mean scores: 20.58 Means Scores[:-10]: 22.30 Score: 20
# Run [ 900] - Total reward: 10681.00 Mean scores: 20.61 Means Scores[:-10]: 22.70 Score: 23
# Run [ 910] - Total reward: 10755.00 Mean scores: 20.63 Means Scores[:-10]: 22.90 Score: 23
# Run [ 920] - Total reward: 10703.00 Mean scores: 20.66 Means Scores[:-10]: 22.80 Score: 23
# Run [ 930] - Total reward: 11389.00 Mean scores: 20.68 Means Scores[:-10]: 23.20 Score: 24
# Run [ 940] - Total reward: 9746.00 Mean scores: 20.71 Means Scores[:-10]: 22.80 Score: 21
# Run [ 950] - Total reward: 10240.00 Mean scores: 20.73 Means Scores[:-10]: 22.80 Score: 22
# Run [ 960] - Total reward: 9574.00 Mean scores: 20.75 Means Scores[:-10]: 22.30 Score: 21
# Run [ 970] - Total reward: 10671.00 Mean scores: 20.77 Means Scores[:-10]: 23.20 Score: 23
# Run [ 980] - Total reward: 10205.00 Mean scores: 20.79 Means Scores[:-10]: 22.60 Score: 22
# Run [ 990] - Total reward: 10927.00 Mean scores: 20.81 Means Scores[:-10]: 23.20 Score: 23
# Run [1000] - Total reward: 10742.00 Mean scores: 20.83 Means Scores[:-10]: 22.70 Score: 23
# Run [1010] - Total reward: 11818.00 Mean scores: 20.86 Means Scores[:-10]: 23.40 Score: 25
# Run [1020] - Total reward: 11204.00 Mean scores: 20.88 Means Scores[:-10]: 22.80 Score: 24
# Run [1030] - Total reward: 10195.00 Mean scores: 20.89 Means Scores[:-10]: 22.40 Score: 22
# Run [1040] - Total reward: 11329.00 Mean scores: 20.92 Means Scores[:-10]: 23.40 Score: 24
# Run [1050] - Total reward: 10816.00 Mean scores: 20.94 Means Scores[:-10]: 23.40 Score: 23
# Run [1060] - Total reward: 10740.00 Mean scores: 20.95 Means Scores[:-10]: 22.60 Score: 23
# Run [1070] - Total reward: 10296.00 Mean scores: 20.97 Means Scores[:-10]: 23.00 Score: 22
# Run [1080] - Total reward: 9151.00 Mean scores: 20.99 Means Scores[:-10]: 22.90 Score: 20
# Run [1090] - Total reward: 11925.00 Mean scores: 21.01 Means Scores[:-10]: 22.60 Score: 25
# Run [1100] - Total reward: 10242.00 Mean scores: 21.02 Means Scores[:-10]: 22.80 Score: 22
# Run [1110] - Total reward: 10178.00 Mean scores: 21.03 Means Scores[:-10]: 22.30 Score: 22
# Run [1120] - Total reward: 10735.00 Mean scores: 21.05 Means Scores[:-10]: 22.60 Score: 23
# Run [1130] - Total reward: 10165.00 Mean scores: 21.07 Means Scores[:-10]: 23.10 Score: 22
# Run [1140] - Total reward: 10849.00 Mean scores: 21.08 Means Scores[:-10]: 22.50 Score: 23
# Run [1150] - Total reward: 9624.00 Mean scores: 21.09 Means Scores[:-10]: 22.60 Score: 21
# Run [1160] - Total reward: 9669.00 Mean scores: 21.11 Means Scores[:-10]: 22.90 Score: 21
# Run [1170] - Total reward: 10648.00 Mean scores: 21.12 Means Scores[:-10]: 22.40 Score: 23
# Run [1180] - Total reward: 10226.00 Mean scores: 21.14 Means Scores[:-10]: 23.10 Score: 22
# Run [1190] - Total reward: 10809.00 Mean scores: 21.15 Means Scores[:-10]: 22.80 Score: 23
# Run [1200] - Total reward: 9651.00 Mean scores: 21.16 Means Scores[:-10]: 22.10 Score: 21
# Run [1210] - Total reward: 10202.00 Mean scores: 21.17 Means Scores[:-10]: 23.20 Score: 22
# Run [1220] - Total reward: 10166.00 Mean scores: 21.18 Means Scores[:-10]: 22.40 Score: 22
# Run [1230] - Total reward: 10860.00 Mean scores: 21.20 Means Scores[:-10]: 23.40 Score: 23
# Run [1240] - Total reward: 10675.00 Mean scores: 21.22 Means Scores[:-10]: 22.90 Score: 23
# Run [1250] - Total reward: 10713.00 Mean scores: 21.23 Means Scores[:-10]: 23.20 Score: 23
# Run [1260] - Total reward: 10182.00 Mean scores: 21.24 Means Scores[:-10]: 22.70 Score: 22
# Run [1270] - Total reward: 11261.00 Mean scores: 21.25 Means Scores[:-10]: 22.50 Score: 24
# Run [1280] - Total reward: 11175.00 Mean scores: 21.27 Means Scores[:-10]: 22.80 Score: 24
# Run [1290] - Total reward: 10749.00 Mean scores: 21.27 Means Scores[:-10]: 22.20 Score: 23
# Run [1300] - Total reward: 10818.00 Mean scores: 21.29 Means Scores[:-10]: 23.80 Score: 23
# Run [1310] - Total reward: 10665.00 Mean scores: 21.31 Means Scores[:-10]: 23.00 Score: 23
# Run [1320] - Total reward: 10110.00 Mean scores: 21.31 Means Scores[:-10]: 22.20 Score: 22
# Run [1330] - Total reward: 11430.00 Mean scores: 21.33 Means Scores[:-10]: 23.10 Score: 24
# Run [1340] - Total reward: 11941.00 Mean scores: 21.33 Means Scores[:-10]: 22.60 Score: 25
# Run [1350] - Total reward: 9305.00 Mean scores: 21.34 Means Scores[:-10]: 22.30 Score: 20
# Run [1360] - Total reward: 10754.00 Mean scores: 21.35 Means Scores[:-10]: 22.40 Score: 23
# Run [1370] - Total reward: 11326.00 Mean scores: 21.36 Means Scores[:-10]: 22.10 Score: 24
# Run [1380] - Total reward: 11306.00 Mean scores: 21.36 Means Scores[:-10]: 22.50 Score: 24
# Run [1390] - Total reward: 11127.00 Mean scores: 21.37 Means Scores[:-10]: 22.90 Score: 24
# Run [1400] - Total reward: 9723.00 Mean scores: 21.38 Means Scores[:-10]: 22.50 Score: 21
# Run [1410] - Total reward: 10149.00 Mean scores: 21.39 Means Scores[:-10]: 23.10 Score: 22
# Run [1420] - Total reward: 9142.00 Mean scores: 21.40 Means Scores[:-10]: 21.80 Score: 20
# Run [1430] - Total reward: 10875.00 Mean scores: 21.41 Means Scores[:-10]: 22.60 Score: 23
# Run [1440] - Total reward: 10735.00 Mean scores: 21.42 Means Scores[:-10]: 23.20 Score: 23
# Run [1450] - Total reward: 11282.00 Mean scores: 21.43 Means Scores[:-10]: 22.60 Score: 24
# Run [1460] - Total reward: 12405.00 Mean scores: 21.44 Means Scores[:-10]: 23.10 Score: 26
# Run [1470] - Total reward: 12304.00 Mean scores: 21.45 Means Scores[:-10]: 22.80 Score: 26
# Run [1480] - Total reward: 9631.00 Mean scores: 21.45 Means Scores[:-10]: 21.90 Score: 21
# Run [1490] - Total reward: 11324.00 Mean scores: 21.46 Means Scores[:-10]: 22.60 Score: 24
# Run [1500] - Total reward: 9739.00 Mean scores: 21.47 Means Scores[:-10]: 22.50 Score: 21
# Run [1510] - Total reward: 11763.00 Mean scores: 21.48 Means Scores[:-10]: 23.70 Score: 25
# Run [1520] - Total reward: 11342.00 Mean scores: 21.49 Means Scores[:-10]: 22.50 Score: 24
# Run [1530] - Total reward: 10233.00 Mean scores: 21.49 Means Scores[:-10]: 21.90 Score: 22
# Run [1540] - Total reward: 10258.00 Mean scores: 21.49 Means Scores[:-10]: 22.30 Score: 22
# Run [1550] - Total reward: 9705.00 Mean scores: 21.50 Means Scores[:-10]: 22.90 Score: 21
# Run [1560] - Total reward: 10726.00 Mean scores: 21.51 Means Scores[:-10]: 23.20 Score: 23
# Run [1570] - Total reward: 10783.00 Mean scores: 21.52 Means Scores[:-10]: 22.90 Score: 23
# Run [1580] - Total reward: 9774.00 Mean scores: 21.53 Means Scores[:-10]: 23.20 Score: 21
# Run [1590] - Total reward: 9544.00 Mean scores: 21.54 Means Scores[:-10]: 22.80 Score: 21
# Run [1600] - Total reward: 9625.00 Mean scores: 21.54 Means Scores[:-10]: 21.30 Score: 21
# Run [1610] - Total reward: 11381.00 Mean scores: 21.55 Means Scores[:-10]: 22.80 Score: 24
# Run [1620] - Total reward: 10236.00 Mean scores: 21.56 Means Scores[:-10]: 23.00 Score: 22
# Run [1630] - Total reward: 11236.00 Mean scores: 21.57 Means Scores[:-10]: 23.00 Score: 24
# Run [1640] - Total reward: 10813.00 Mean scores: 21.57 Means Scores[:-10]: 22.20 Score: 23
# Run [1650] - Total reward: 12491.00 Mean scores: 21.58 Means Scores[:-10]: 22.80 Score: 26
# Run [1660] - Total reward: 10707.00 Mean scores: 21.58 Means Scores[:-10]: 22.60 Score: 23
# Run [1670] - Total reward: 10161.00 Mean scores: 21.59 Means Scores[:-10]: 22.50 Score: 22
# Run [1680] - Total reward: 11246.00 Mean scores: 21.60 Means Scores[:-10]: 23.10 Score: 24
# Run [1690] - Total reward: 11251.00 Mean scores: 21.60 Means Scores[:-10]: 22.70 Score: 24
# Run [1700] - Total reward: 9778.00 Mean scores: 21.61 Means Scores[:-10]: 22.80 Score: 21
# Run [1710] - Total reward: 9756.00 Mean scores: 21.62 Means Scores[:-10]: 22.70 Score: 21
# Run [1720] - Total reward: 11354.00 Mean scores: 21.62 Means Scores[:-10]: 22.40 Score: 24
# Run [1730] - Total reward: 9712.00 Mean scores: 21.62 Means Scores[:-10]: 21.80 Score: 21
# Run [1740] - Total reward: 11182.00 Mean scores: 21.63 Means Scores[:-10]: 22.20 Score: 24
# Run [1750] - Total reward: 10279.00 Mean scores: 21.63 Means Scores[:-10]: 22.50 Score: 22
# Run [1760] - Total reward: 10265.00 Mean scores: 21.63 Means Scores[:-10]: 22.20 Score: 22
# Run [1770] - Total reward: 10754.00 Mean scores: 21.64 Means Scores[:-10]: 22.90 Score: 23
# Run [1780] - Total reward: 10893.00 Mean scores: 21.65 Means Scores[:-10]: 22.80 Score: 23
# Run [1790] - Total reward: 10079.00 Mean scores: 21.66 Means Scores[:-10]: 23.00 Score: 22
# Run [1800] - Total reward: 10285.00 Mean scores: 21.66 Means Scores[:-10]: 22.00 Score: 22
# Run [1810] - Total reward: 10167.00 Mean scores: 21.66 Means Scores[:-10]: 21.90 Score: 22
# Run [1820] - Total reward: 11967.00 Mean scores: 21.67 Means Scores[:-10]: 22.90 Score: 25
# Run [1830] - Total reward: 9110.00 Mean scores: 21.67 Means Scores[:-10]: 21.90 Score: 20
# Run [1840] - Total reward: 10245.00 Mean scores: 21.67 Means Scores[:-10]: 22.50 Score: 22
# Run [1850] - Total reward: 11439.00 Mean scores: 21.68 Means Scores[:-10]: 22.70 Score: 24
# Run [1860] - Total reward: 9771.00 Mean scores: 21.69 Means Scores[:-10]: 23.40 Score: 21
# Run [1870] - Total reward: 9714.00 Mean scores: 21.69 Means Scores[:-10]: 22.10 Score: 21
# Run [1880] - Total reward: 10301.00 Mean scores: 21.69 Means Scores[:-10]: 22.70 Score: 22
# Run [1890] - Total reward: 10290.00 Mean scores: 21.70 Means Scores[:-10]: 22.70 Score: 22
# Run [1900] - Total reward: 10663.00 Mean scores: 21.71 Means Scores[:-10]: 23.30 Score: 23
# Run [1910] - Total reward: 10701.00 Mean scores: 21.71 Means Scores[:-10]: 21.90 Score: 23
# Run [1920] - Total reward: 11421.00 Mean scores: 21.71 Means Scores[:-10]: 22.50 Score: 24
# Run [1930] - Total reward: 9770.00 Mean scores: 21.72 Means Scores[:-10]: 22.50 Score: 21
# Run [1940] - Total reward: 10397.00 Mean scores: 21.72 Means Scores[:-10]: 22.30 Score: 22
# Run [1950] - Total reward: 10274.00 Mean scores: 21.72 Means Scores[:-10]: 22.60 Score: 22
# Run [1960] - Total reward: 10294.00 Mean scores: 21.73 Means Scores[:-10]: 22.00 Score: 22
# Run [1970] - Total reward: 10226.00 Mean scores: 21.73 Means Scores[:-10]: 22.20 Score: 22

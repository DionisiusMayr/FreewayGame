# %%
import sys
sys.path.append('/content/FreewayGame/leonardo/')
# %matplotlib inline
from collections import defaultdict
from typing import List

import numpy as np
import time
import matplotlib.pyplot as plt
import seaborn as sns

import gym

import src.agents as agents
import src.episode as episode
import src.environment as environment
import src.aux_plots as aux_plots
import src.serializer as serializer

# %%
def print_result(i, scores, total_reward, score):
    if i % 10 == 0:
        print(f"Run [{i:4}] - Total reward: {total_reward:7.2f} Mean scores: {sum(scores) / len(scores):.2f} Means Scores[:-10]: {sum(scores[-10:]) / len(scores[-10:]):5.2f} Score: {score:2} ")

# %%
RAM_mask = [
      14  # Chicken Y
    , 16  # Chicken Lane Collide
    , 108, 109, 110, 111, 112, 113, 114, 115, 116, 117  # Car X Coords
]

# %%
def reduce_state(ob):
    # Doesn't matter where we were hit
    ob[16] = 1 if ob[16] != 255 else 0

    # Reduce chicken y-position
    ob[14] = ob[14] // 3

    for b in range(108, 118):
        # The chicken is in the x-posistion ~49
        if ob[b] < 20 or ob[b] > 80:
            # We don't need to represent cars far from the chicken
            ob[b] = 0
        else:
            # Reduce the cars x-positions sample space
            ob[b] = ob[b] // 3

    return ob
    
def reward_policy(reward, ob, action):
    if reward == 1:
        reward = reward_policy.REWARD_IF_CROSS
    elif ob[16] == 1:  # Collision!
        reward = reward_policy.REWARD_IF_COLISION
    elif action != 1:  # Don't incentivate staying still
        reward = reward_policy.REWARD_IF_STILL

    return reward

def train(agent, env, name, n_runs=5000, n_render=500, n_print=10):
    scores = []
    total_rewards = []
    for i in range(n_runs):
        render = i % n_render == (n_render-1)

        E = defaultdict(lambda: np.zeros(2))

        game_over = False
        state = env.reset()
        state = reduce_state(state)[RAM_mask].data.tobytes()  # Select useful bytes
        action = agent.act(state)

        score = 0
        total_reward = 0

        while not game_over:
            if render:
                time.sleep(0.005)
                env.render()

            old_state = state
            old_action = action
            ob, reward, game_over, _ = env.step(action)

            ob = reduce_state(ob)
            reward = reward_policy(reward, ob, action)

            total_reward += reward

            if reward == reward_policy.REWARD_IF_CROSS:
                score += 1

            state = ob[RAM_mask].data.tobytes()

            action = agent.act(state)  # Next action

            E[old_state][old_action] += 1

            agent.update(old_s=old_state, new_s=state, old_a=old_action, new_a=action, reward=reward, E=i+1)

        scores.append(score)
        total_rewards.append(total_reward)
        
        if i%500 == 499:
        
            exp = serializer.Experiment(agent, scores, total_rewards, reduce_state, reward_policy)
            exp.save_experiment(name)

        if i % n_print == 0:
            print(f"Run [{i:4}] - Total reward: {total_reward:7.2f} Mean scores: {sum(scores) / len(scores):.2f} Means Scores[:-10]: {sum(scores[-10:]) / len(scores[-10:]):5.2f} Score: {score:2} ")
    return scores, total_rewards

# %%
def run_adam_experiment(name, n_runs=2500, AVAILABLE_ACTIONS = 2, GAMMA = 0.99, N0 = 2.5, ALPHA = 0.001,
                        LAMB = 0.00, REWARD_IF_CROSS=500, REWARD_IF_COLISION=-10, REWARD_IF_STILL=-1):

    env, initial_state = environment.get_env()
    
    reward_policy.REWARD_IF_CROSS = REWARD_IF_CROSS
    reward_policy.REWARD_IF_COLISION = REWARD_IF_COLISION
    reward_policy.REWARD_IF_STILL = REWARD_IF_STILL

    agent = agents.SarsaLFAADAM(gamma=GAMMA, state_size=len(RAM_mask), available_actions=AVAILABLE_ACTIONS, N0=N0, alpha=ALPHA, lamb=LAMB)
    agent.trainScaler(env, RAM_mask)

    
    scores, total_rewards = train(agent, env, name, n_runs=n_runs, n_render=500, n_print=10)
    aux_plots.plot_scores(scores)
    aux_plots.plot_rewards(total_rewards)

# %%
# %%time
run_adam_experiment('adam_n25', N0 = 2.5)
# Out:
# Run [   0] - Total reward: 3924.00 Mean scores: 12.00 Means Scores[:-10]: 12.00 Score: 12
# Run [  10] - Total reward: 4666.00 Mean scores: 12.09 Means Scores[:-10]: 12.10 Score: 13
# Run [  20] - Total reward: 4200.00 Mean scores: 12.86 Means Scores[:-10]: 13.70 Score: 12
# Run [  30] - Total reward: 5900.00 Mean scores: 13.55 Means Scores[:-10]: 15.00 Score: 15
# Run [  40] - Total reward: 8018.00 Mean scores: 14.20 Means Scores[:-10]: 16.20 Score: 19
# Run [  50] - Total reward: 8153.00 Mean scores: 14.80 Means Scores[:-10]: 17.30 Score: 19
# Run [  60] - Total reward: 6973.00 Mean scores: 15.31 Means Scores[:-10]: 17.90 Score: 17
# Run [  70] - Total reward: 7004.00 Mean scores: 15.65 Means Scores[:-10]: 17.70 Score: 17
# Run [  80] - Total reward: 7636.00 Mean scores: 15.88 Means Scores[:-10]: 17.50 Score: 18
# Run [  90] - Total reward: 6054.00 Mean scores: 16.05 Means Scores[:-10]: 17.50 Score: 15
# Run [ 100] - Total reward: 7190.00 Mean scores: 16.21 Means Scores[:-10]: 17.60 Score: 17
# Run [ 110] - Total reward: 7156.00 Mean scores: 16.37 Means Scores[:-10]: 18.00 Score: 17
# Run [ 120] - Total reward: 7126.00 Mean scores: 16.55 Means Scores[:-10]: 18.50 Score: 17
# Run [ 130] - Total reward: 8956.00 Mean scores: 16.73 Means Scores[:-10]: 18.90 Score: 20
# Run [ 140] - Total reward: 7798.00 Mean scores: 16.89 Means Scores[:-10]: 19.00 Score: 18
# Run [ 150] - Total reward: 8944.00 Mean scores: 17.02 Means Scores[:-10]: 18.90 Score: 20
# Run [ 160] - Total reward: 8957.00 Mean scores: 17.11 Means Scores[:-10]: 18.50 Score: 20
# Run [ 170] - Total reward: 7940.00 Mean scores: 17.20 Means Scores[:-10]: 18.70 Score: 18
# Run [ 180] - Total reward: 10059.00 Mean scores: 17.31 Means Scores[:-10]: 19.10 Score: 22
# Run [ 190] - Total reward: 8200.00 Mean scores: 17.35 Means Scores[:-10]: 18.10 Score: 19
# Run [ 200] - Total reward: 7383.00 Mean scores: 17.42 Means Scores[:-10]: 18.70 Score: 17
# Run [ 210] - Total reward: 8897.00 Mean scores: 17.48 Means Scores[:-10]: 18.80 Score: 20
# Run [ 220] - Total reward: 8964.00 Mean scores: 17.57 Means Scores[:-10]: 19.40 Score: 20
# Run [ 230] - Total reward: 7888.00 Mean scores: 17.67 Means Scores[:-10]: 19.90 Score: 18
# Run [ 240] - Total reward: 10014.00 Mean scores: 17.74 Means Scores[:-10]: 19.40 Score: 22
# Run [ 250] - Total reward: 8446.00 Mean scores: 17.83 Means Scores[:-10]: 20.00 Score: 19
# Run [ 260] - Total reward: 8505.00 Mean scores: 17.90 Means Scores[:-10]: 19.60 Score: 19
# Run [ 270] - Total reward: 7905.00 Mean scores: 17.97 Means Scores[:-10]: 19.70 Score: 18
# Run [ 280] - Total reward: 8908.00 Mean scores: 18.04 Means Scores[:-10]: 19.90 Score: 20
# Run [ 290] - Total reward: 8914.00 Mean scores: 18.10 Means Scores[:-10]: 20.00 Score: 20
# Run [ 300] - Total reward: 9038.00 Mean scores: 18.18 Means Scores[:-10]: 20.40 Score: 20
# Run [ 310] - Total reward: 7899.00 Mean scores: 18.23 Means Scores[:-10]: 19.70 Score: 18
# Run [ 320] - Total reward: 10013.00 Mean scores: 18.28 Means Scores[:-10]: 20.00 Score: 22
# Run [ 330] - Total reward: 8449.00 Mean scores: 18.34 Means Scores[:-10]: 20.00 Score: 19
# Run [ 340] - Total reward: 9086.00 Mean scores: 18.38 Means Scores[:-10]: 19.90 Score: 20
# Run [ 350] - Total reward: 9426.00 Mean scores: 18.44 Means Scores[:-10]: 20.50 Score: 21
# Run [ 360] - Total reward: 10023.00 Mean scores: 18.51 Means Scores[:-10]: 20.90 Score: 22
# Run [ 370] - Total reward: 8508.00 Mean scores: 18.55 Means Scores[:-10]: 20.00 Score: 19
# Run [ 380] - Total reward: 10532.00 Mean scores: 18.61 Means Scores[:-10]: 21.00 Score: 23
# Run [ 390] - Total reward: 8886.00 Mean scores: 18.68 Means Scores[:-10]: 21.30 Score: 20
# Run [ 400] - Total reward: 10564.00 Mean scores: 18.75 Means Scores[:-10]: 21.20 Score: 23
# Run [ 410] - Total reward: 10069.00 Mean scores: 18.79 Means Scores[:-10]: 20.60 Score: 22
# Run [ 420] - Total reward: 8498.00 Mean scores: 18.86 Means Scores[:-10]: 21.60 Score: 19
# Run [ 430] - Total reward: 7919.00 Mean scores: 18.90 Means Scores[:-10]: 20.50 Score: 18
# Run [ 440] - Total reward: 8434.00 Mean scores: 18.93 Means Scores[:-10]: 20.50 Score: 19
# Run [ 450] - Total reward: 10681.00 Mean scores: 18.98 Means Scores[:-10]: 21.10 Score: 23
# Run [ 460] - Total reward: 7936.00 Mean scores: 19.03 Means Scores[:-10]: 21.10 Score: 18
# Run [ 470] - Total reward: 9575.00 Mean scores: 19.08 Means Scores[:-10]: 21.50 Score: 21
# Run [ 480] - Total reward: 10740.00 Mean scores: 19.15 Means Scores[:-10]: 22.30 Score: 23
# Run [ 490] - Total reward: 10116.00 Mean scores: 19.20 Means Scores[:-10]: 22.00 Score: 22
# Run [ 500] - Total reward: 9666.00 Mean scores: 19.24 Means Scores[:-10]: 21.20 Score: 21
# Run [ 510] - Total reward: 10651.00 Mean scores: 19.30 Means Scores[:-10]: 22.10 Score: 23
# Run [ 520] - Total reward: 10131.00 Mean scores: 19.35 Means Scores[:-10]: 21.70 Score: 22
# Run [ 530] - Total reward: 9159.00 Mean scores: 19.38 Means Scores[:-10]: 21.40 Score: 20
# Run [ 540] - Total reward: 10706.00 Mean scores: 19.42 Means Scores[:-10]: 21.40 Score: 23
# Run [ 550] - Total reward: 10216.00 Mean scores: 19.46 Means Scores[:-10]: 21.50 Score: 22
# Run [ 560] - Total reward: 9505.00 Mean scores: 19.49 Means Scores[:-10]: 21.30 Score: 21
# Run [ 570] - Total reward: 9604.00 Mean scores: 19.54 Means Scores[:-10]: 22.00 Score: 21
# Run [ 580] - Total reward: 9554.00 Mean scores: 19.57 Means Scores[:-10]: 21.50 Score: 21
# Run [ 590] - Total reward: 9134.00 Mean scores: 19.60 Means Scores[:-10]: 21.60 Score: 20
# Run [ 600] - Total reward: 10218.00 Mean scores: 19.64 Means Scores[:-10]: 21.70 Score: 22
# Run [ 610] - Total reward: 10719.00 Mean scores: 19.67 Means Scores[:-10]: 21.60 Score: 23
# Run [ 620] - Total reward: 10188.00 Mean scores: 19.70 Means Scores[:-10]: 21.70 Score: 22
# Run [ 630] - Total reward: 9617.00 Mean scores: 19.73 Means Scores[:-10]: 21.40 Score: 21
# Run [ 640] - Total reward: 10818.00 Mean scores: 19.76 Means Scores[:-10]: 21.30 Score: 23
# Run [ 650] - Total reward: 9618.00 Mean scores: 19.80 Means Scores[:-10]: 22.70 Score: 21
# Run [ 660] - Total reward: 9100.00 Mean scores: 19.84 Means Scores[:-10]: 22.40 Score: 20
# Run [ 670] - Total reward: 9522.00 Mean scores: 19.88 Means Scores[:-10]: 22.30 Score: 21
# Run [ 680] - Total reward: 9593.00 Mean scores: 19.91 Means Scores[:-10]: 22.20 Score: 21
# Run [ 690] - Total reward: 10190.00 Mean scores: 19.94 Means Scores[:-10]: 22.10 Score: 22
# Run [ 700] - Total reward: 10133.00 Mean scores: 19.98 Means Scores[:-10]: 22.30 Score: 22
# Run [ 710] - Total reward: 11297.00 Mean scores: 20.01 Means Scores[:-10]: 22.40 Score: 24
# Run [ 720] - Total reward: 10782.00 Mean scores: 20.04 Means Scores[:-10]: 22.50 Score: 23
# Run [ 730] - Total reward: 10217.00 Mean scores: 20.07 Means Scores[:-10]: 22.00 Score: 22
# Run [ 740] - Total reward: 10739.00 Mean scores: 20.11 Means Scores[:-10]: 22.70 Score: 23
# Run [ 750] - Total reward: 10709.00 Mean scores: 20.14 Means Scores[:-10]: 22.30 Score: 23
# Run [ 760] - Total reward: 10108.00 Mean scores: 20.16 Means Scores[:-10]: 22.20 Score: 22
# Run [ 770] - Total reward: 10746.00 Mean scores: 20.20 Means Scores[:-10]: 23.10 Score: 23
# Run [ 780] - Total reward: 11834.00 Mean scores: 20.23 Means Scores[:-10]: 22.80 Score: 25
# Run [ 790] - Total reward: 10797.00 Mean scores: 20.27 Means Scores[:-10]: 22.90 Score: 23
# Run [ 800] - Total reward: 11154.00 Mean scores: 20.30 Means Scores[:-10]: 23.00 Score: 24
# Run [ 810] - Total reward: 10741.00 Mean scores: 20.33 Means Scores[:-10]: 22.60 Score: 23
# Run [ 820] - Total reward: 11205.00 Mean scores: 20.36 Means Scores[:-10]: 23.10 Score: 24
# Run [ 830] - Total reward: 10776.00 Mean scores: 20.39 Means Scores[:-10]: 22.70 Score: 23
# Run [ 840] - Total reward: 10783.00 Mean scores: 20.43 Means Scores[:-10]: 23.20 Score: 23
# Run [ 850] - Total reward: 10700.00 Mean scores: 20.46 Means Scores[:-10]: 23.10 Score: 23
# Run [ 860] - Total reward: 11312.00 Mean scores: 20.48 Means Scores[:-10]: 22.70 Score: 24
# Run [ 870] - Total reward: 10767.00 Mean scores: 20.51 Means Scores[:-10]: 23.00 Score: 23
# Run [ 880] - Total reward: 11330.00 Mean scores: 20.54 Means Scores[:-10]: 23.10 Score: 24
# Run [ 890] - Total reward: 10746.00 Mean scores: 20.57 Means Scores[:-10]: 22.80 Score: 23
# Run [ 900] - Total reward: 10190.00 Mean scores: 20.59 Means Scores[:-10]: 22.70 Score: 22
# Run [ 910] - Total reward: 9653.00 Mean scores: 20.62 Means Scores[:-10]: 23.10 Score: 21
# Run [ 920] - Total reward: 10768.00 Mean scores: 20.65 Means Scores[:-10]: 23.20 Score: 23
# Run [ 930] - Total reward: 10826.00 Mean scores: 20.67 Means Scores[:-10]: 23.20 Score: 23
# Run [ 940] - Total reward: 10283.00 Mean scores: 20.70 Means Scores[:-10]: 23.10 Score: 22
# Run [ 950] - Total reward: 11787.00 Mean scores: 20.72 Means Scores[:-10]: 22.60 Score: 25
# Run [ 960] - Total reward: 11859.00 Mean scores: 20.75 Means Scores[:-10]: 23.60 Score: 25
# Run [ 970] - Total reward: 11315.00 Mean scores: 20.77 Means Scores[:-10]: 22.80 Score: 24
# Run [ 980] - Total reward: 10193.00 Mean scores: 20.79 Means Scores[:-10]: 22.70 Score: 22
# Run [ 990] - Total reward: 11289.00 Mean scores: 20.81 Means Scores[:-10]: 22.70 Score: 24
# Run [1000] - Total reward: 10795.00 Mean scores: 20.83 Means Scores[:-10]: 22.90 Score: 23
# Run [1010] - Total reward: 9771.00 Mean scores: 20.85 Means Scores[:-10]: 22.60 Score: 21
# Run [1020] - Total reward: 10764.00 Mean scores: 20.87 Means Scores[:-10]: 23.20 Score: 23
# Run [1030] - Total reward: 10265.00 Mean scores: 20.89 Means Scores[:-10]: 22.60 Score: 22
# Run [1040] - Total reward: 11316.00 Mean scores: 20.91 Means Scores[:-10]: 23.10 Score: 24
# Run [1050] - Total reward: 11244.00 Mean scores: 20.93 Means Scores[:-10]: 23.00 Score: 24
# Run [1060] - Total reward: 10287.00 Mean scores: 20.94 Means Scores[:-10]: 22.50 Score: 22
# Run [1070] - Total reward: 10754.00 Mean scores: 20.96 Means Scores[:-10]: 22.30 Score: 23
# Run [1080] - Total reward: 11363.00 Mean scores: 20.97 Means Scores[:-10]: 22.80 Score: 24
# Run [1090] - Total reward: 11714.00 Mean scores: 21.00 Means Scores[:-10]: 23.40 Score: 25
# Run [1100] - Total reward: 10736.00 Mean scores: 21.01 Means Scores[:-10]: 22.60 Score: 23
# Run [1110] - Total reward: 10319.00 Mean scores: 21.02 Means Scores[:-10]: 22.60 Score: 22
# Run [1120] - Total reward: 11857.00 Mean scores: 21.04 Means Scores[:-10]: 23.20 Score: 25
# Run [1130] - Total reward: 11301.00 Mean scores: 21.06 Means Scores[:-10]: 23.00 Score: 24
# Run [1140] - Total reward: 10263.00 Mean scores: 21.08 Means Scores[:-10]: 22.80 Score: 22
# Run [1150] - Total reward: 11276.00 Mean scores: 21.09 Means Scores[:-10]: 23.20 Score: 24
# Run [1160] - Total reward: 10682.00 Mean scores: 21.11 Means Scores[:-10]: 22.30 Score: 23
# Run [1170] - Total reward: 10814.00 Mean scores: 21.12 Means Scores[:-10]: 22.70 Score: 23
# Run [1180] - Total reward: 9652.00 Mean scores: 21.13 Means Scores[:-10]: 22.40 Score: 21
# Run [1190] - Total reward: 10191.00 Mean scores: 21.14 Means Scores[:-10]: 22.50 Score: 22
# Run [1200] - Total reward: 12350.00 Mean scores: 21.16 Means Scores[:-10]: 23.10 Score: 26
# Run [1210] - Total reward: 10801.00 Mean scores: 21.17 Means Scores[:-10]: 23.10 Score: 23
# Run [1220] - Total reward: 9575.00 Mean scores: 21.19 Means Scores[:-10]: 22.60 Score: 21
# Run [1230] - Total reward: 11243.00 Mean scores: 21.19 Means Scores[:-10]: 22.20 Score: 24
# Run [1240] - Total reward: 10191.00 Mean scores: 21.20 Means Scores[:-10]: 22.30 Score: 22
# Run [1250] - Total reward: 10105.00 Mean scores: 21.21 Means Scores[:-10]: 22.40 Score: 22
# Run [1260] - Total reward: 10746.00 Mean scores: 21.22 Means Scores[:-10]: 22.40 Score: 23
# Run [1270] - Total reward: 10200.00 Mean scores: 21.23 Means Scores[:-10]: 22.60 Score: 22
# Run [1280] - Total reward: 10715.00 Mean scores: 21.25 Means Scores[:-10]: 22.90 Score: 23
# Run [1290] - Total reward: 11831.00 Mean scores: 21.26 Means Scores[:-10]: 22.70 Score: 25
# Run [1300] - Total reward: 10305.00 Mean scores: 21.27 Means Scores[:-10]: 23.30 Score: 22
# Run [1310] - Total reward: 9770.00 Mean scores: 21.28 Means Scores[:-10]: 22.20 Score: 21
# Run [1320] - Total reward: 10174.00 Mean scores: 21.29 Means Scores[:-10]: 22.40 Score: 22
# Run [1330] - Total reward: 11201.00 Mean scores: 21.30 Means Scores[:-10]: 22.70 Score: 24
# Run [1340] - Total reward: 9694.00 Mean scores: 21.31 Means Scores[:-10]: 22.40 Score: 21
# Run [1350] - Total reward: 11789.00 Mean scores: 21.32 Means Scores[:-10]: 22.70 Score: 25
# Run [1360] - Total reward: 11241.00 Mean scores: 21.33 Means Scores[:-10]: 23.60 Score: 24
# Run [1370] - Total reward: 9620.00 Mean scores: 21.34 Means Scores[:-10]: 22.20 Score: 21
# Run [1380] - Total reward: 10841.00 Mean scores: 21.35 Means Scores[:-10]: 22.40 Score: 23
# Run [1390] - Total reward: 9244.00 Mean scores: 21.35 Means Scores[:-10]: 21.70 Score: 20
# Run [1400] - Total reward: 9101.00 Mean scores: 21.36 Means Scores[:-10]: 22.40 Score: 20
# Run [1410] - Total reward: 11277.00 Mean scores: 21.37 Means Scores[:-10]: 23.30 Score: 24
# Run [1420] - Total reward: 11204.00 Mean scores: 21.38 Means Scores[:-10]: 22.80 Score: 24
# Run [1430] - Total reward: 10162.00 Mean scores: 21.39 Means Scores[:-10]: 22.50 Score: 22
# Run [1440] - Total reward: 10648.00 Mean scores: 21.40 Means Scores[:-10]: 23.00 Score: 23
# Run [1450] - Total reward: 10229.00 Mean scores: 21.41 Means Scores[:-10]: 22.50 Score: 22
# Run [1460] - Total reward: 10796.00 Mean scores: 21.42 Means Scores[:-10]: 22.70 Score: 23
# Run [1470] - Total reward: 9778.00 Mean scores: 21.42 Means Scores[:-10]: 21.90 Score: 21
# Run [1480] - Total reward: 10196.00 Mean scores: 21.43 Means Scores[:-10]: 22.20 Score: 22
# Run [1490] - Total reward: 9659.00 Mean scores: 21.44 Means Scores[:-10]: 23.00 Score: 21
# Run [1500] - Total reward: 11207.00 Mean scores: 21.45 Means Scores[:-10]: 22.90 Score: 24
# Run [1510] - Total reward: 10783.00 Mean scores: 21.45 Means Scores[:-10]: 22.30 Score: 23
# Run [1520] - Total reward: 10312.00 Mean scores: 21.46 Means Scores[:-10]: 22.90 Score: 22
# Run [1530] - Total reward: 10758.00 Mean scores: 21.47 Means Scores[:-10]: 22.80 Score: 23
# Run [1540] - Total reward: 10290.00 Mean scores: 21.47 Means Scores[:-10]: 22.20 Score: 22
# Run [1550] - Total reward: 10175.00 Mean scores: 21.48 Means Scores[:-10]: 23.00 Score: 22
# Run [1560] - Total reward: 11283.00 Mean scores: 21.49 Means Scores[:-10]: 21.90 Score: 24
# Run [1570] - Total reward: 10193.00 Mean scores: 21.49 Means Scores[:-10]: 22.50 Score: 22
# Run [1580] - Total reward: 10179.00 Mean scores: 21.50 Means Scores[:-10]: 22.30 Score: 22
# Run [1590] - Total reward: 10880.00 Mean scores: 21.50 Means Scores[:-10]: 22.20 Score: 23
# Run [1600] - Total reward: 11365.00 Mean scores: 21.51 Means Scores[:-10]: 22.90 Score: 24
# Run [1610] - Total reward: 10618.00 Mean scores: 21.52 Means Scores[:-10]: 22.70 Score: 23
# Run [1620] - Total reward: 10703.00 Mean scores: 21.53 Means Scores[:-10]: 22.60 Score: 23
# Run [1630] - Total reward: 11255.00 Mean scores: 21.53 Means Scores[:-10]: 22.70 Score: 24
# Run [1640] - Total reward: 10156.00 Mean scores: 21.54 Means Scores[:-10]: 22.60 Score: 22
# Run [1650] - Total reward: 10745.00 Mean scores: 21.55 Means Scores[:-10]: 22.50 Score: 23
# Run [1660] - Total reward: 10715.00 Mean scores: 21.55 Means Scores[:-10]: 22.10 Score: 23
# Run [1670] - Total reward: 11310.00 Mean scores: 21.55 Means Scores[:-10]: 22.50 Score: 24
# Run [1680] - Total reward: 11329.00 Mean scores: 21.56 Means Scores[:-10]: 22.80 Score: 24
# Run [1690] - Total reward: 10142.00 Mean scores: 21.57 Means Scores[:-10]: 22.40 Score: 22
# Run [1700] - Total reward: 10145.00 Mean scores: 21.57 Means Scores[:-10]: 22.40 Score: 22
# Run [1710] - Total reward: 11432.00 Mean scores: 21.58 Means Scores[:-10]: 22.40 Score: 24
# Run [1720] - Total reward: 10203.00 Mean scores: 21.58 Means Scores[:-10]: 22.70 Score: 22
# Run [1730] - Total reward: 10819.00 Mean scores: 21.59 Means Scores[:-10]: 22.70 Score: 23
# Run [1740] - Total reward: 10812.00 Mean scores: 21.59 Means Scores[:-10]: 22.40 Score: 23
# Run [1750] - Total reward: 9784.00 Mean scores: 21.60 Means Scores[:-10]: 22.50 Score: 21
# Run [1760] - Total reward: 12504.00 Mean scores: 21.60 Means Scores[:-10]: 21.80 Score: 26
# Run [1770] - Total reward: 10880.00 Mean scores: 21.60 Means Scores[:-10]: 22.10 Score: 23
# Run [1780] - Total reward: 10343.00 Mean scores: 21.61 Means Scores[:-10]: 23.10 Score: 22
# Run [1790] - Total reward: 10116.00 Mean scores: 21.62 Means Scores[:-10]: 22.70 Score: 22
# Run [1800] - Total reward: 10193.00 Mean scores: 21.62 Means Scores[:-10]: 22.50 Score: 22
# Run [1810] - Total reward: 9687.00 Mean scores: 21.63 Means Scores[:-10]: 22.60 Score: 21
# Run [1820] - Total reward: 10862.00 Mean scores: 21.63 Means Scores[:-10]: 22.50 Score: 23
# Run [1830] - Total reward: 9672.00 Mean scores: 21.64 Means Scores[:-10]: 22.40 Score: 21
# Run [1840] - Total reward: 10224.00 Mean scores: 21.64 Means Scores[:-10]: 22.10 Score: 22
# Run [1850] - Total reward: 11387.00 Mean scores: 21.65 Means Scores[:-10]: 22.80 Score: 24
# Run [1860] - Total reward: 10819.00 Mean scores: 21.65 Means Scores[:-10]: 22.50 Score: 23
# Run [1870] - Total reward: 10853.00 Mean scores: 21.65 Means Scores[:-10]: 22.20 Score: 23
# Run [1880] - Total reward: 9190.00 Mean scores: 21.66 Means Scores[:-10]: 22.20 Score: 20
# Run [1890] - Total reward: 10246.00 Mean scores: 21.66 Means Scores[:-10]: 21.80 Score: 22
# Run [1900] - Total reward: 10183.00 Mean scores: 21.66 Means Scores[:-10]: 22.60 Score: 22
# Run [1910] - Total reward: 10368.00 Mean scores: 21.66 Means Scores[:-10]: 22.00 Score: 22
# Run [1920] - Total reward: 9648.00 Mean scores: 21.67 Means Scores[:-10]: 22.50 Score: 21
# Run [1930] - Total reward: 10697.00 Mean scores: 21.67 Means Scores[:-10]: 22.40 Score: 23
# Run [1940] - Total reward: 10169.00 Mean scores: 21.68 Means Scores[:-10]: 22.50 Score: 22
# Run [1950] - Total reward: 10243.00 Mean scores: 21.68 Means Scores[:-10]: 22.00 Score: 22
# Run [1960] - Total reward: 10879.00 Mean scores: 21.68 Means Scores[:-10]: 22.10 Score: 23
# Run [1970] - Total reward: 10206.00 Mean scores: 21.68 Means Scores[:-10]: 22.40 Score: 22
# Run [1980] - Total reward: 11261.00 Mean scores: 21.69 Means Scores[:-10]: 22.90 Score: 24
# Run [1990] - Total reward: 11365.00 Mean scores: 21.69 Means Scores[:-10]: 22.30 Score: 24
# Run [2000] - Total reward: 11752.00 Mean scores: 21.70 Means Scores[:-10]: 22.50 Score: 25
# Run [2010] - Total reward: 10302.00 Mean scores: 21.70 Means Scores[:-10]: 22.70 Score: 22
# Run [2020] - Total reward: 11280.00 Mean scores: 21.71 Means Scores[:-10]: 22.90 Score: 24
# Run [2030] - Total reward: 11309.00 Mean scores: 21.71 Means Scores[:-10]: 22.30 Score: 24
# Run [2040] - Total reward: 10323.00 Mean scores: 21.71 Means Scores[:-10]: 22.10 Score: 22
# Run [2050] - Total reward: 10923.00 Mean scores: 21.72 Means Scores[:-10]: 22.60 Score: 23
# Run [2060] - Total reward: 10731.00 Mean scores: 21.72 Means Scores[:-10]: 22.80 Score: 23
# Run [2070] - Total reward: 10098.00 Mean scores: 21.73 Means Scores[:-10]: 22.50 Score: 22
# Run [2080] - Total reward: 10260.00 Mean scores: 21.73 Means Scores[:-10]: 22.50 Score: 22
# Run [2090] - Total reward: 9204.00 Mean scores: 21.73 Means Scores[:-10]: 22.60 Score: 20
# Run [2100] - Total reward: 10249.00 Mean scores: 21.74 Means Scores[:-10]: 23.10 Score: 22
# Run [2110] - Total reward: 10335.00 Mean scores: 21.74 Means Scores[:-10]: 22.50 Score: 22
# Run [2120] - Total reward: 10275.00 Mean scores: 21.75 Means Scores[:-10]: 22.70 Score: 22
# Run [2130] - Total reward: 10800.00 Mean scores: 21.75 Means Scores[:-10]: 22.50 Score: 23
# Run [2140] - Total reward: 10931.00 Mean scores: 21.75 Means Scores[:-10]: 22.40 Score: 23
# Run [2150] - Total reward: 10835.00 Mean scores: 21.76 Means Scores[:-10]: 22.90 Score: 23
# Run [2160] - Total reward: 10327.00 Mean scores: 21.76 Means Scores[:-10]: 22.20 Score: 22
# Run [2170] - Total reward: 10284.00 Mean scores: 21.77 Means Scores[:-10]: 22.50 Score: 22
# Run [2180] - Total reward: 9060.00 Mean scores: 21.77 Means Scores[:-10]: 23.40 Score: 20
# Run [2190] - Total reward: 10857.00 Mean scores: 21.78 Means Scores[:-10]: 22.80 Score: 23
# Run [2200] - Total reward: 10786.00 Mean scores: 21.78 Means Scores[:-10]: 22.70 Score: 23
# Run [2210] - Total reward: 11222.00 Mean scores: 21.79 Means Scores[:-10]: 22.50 Score: 24
# Run [2220] - Total reward: 11272.00 Mean scores: 21.79 Means Scores[:-10]: 22.60 Score: 24
# Run [2230] - Total reward: 11236.00 Mean scores: 21.79 Means Scores[:-10]: 22.90 Score: 24
# Run [2240] - Total reward: 10789.00 Mean scores: 21.80 Means Scores[:-10]: 22.90 Score: 23
# Run [2250] - Total reward: 9755.00 Mean scores: 21.80 Means Scores[:-10]: 23.00 Score: 21
# Run [2260] - Total reward: 9628.00 Mean scores: 21.81 Means Scores[:-10]: 23.00 Score: 21
# Run [2270] - Total reward: 10315.00 Mean scores: 21.81 Means Scores[:-10]: 22.50 Score: 22
# Run [2280] - Total reward: 11866.00 Mean scores: 21.82 Means Scores[:-10]: 23.60 Score: 25
# Run [2290] - Total reward: 9715.00 Mean scores: 21.82 Means Scores[:-10]: 22.50 Score: 21
# Run [2300] - Total reward: 10305.00 Mean scores: 21.83 Means Scores[:-10]: 22.50 Score: 22
# Run [2310] - Total reward: 11276.00 Mean scores: 21.83 Means Scores[:-10]: 23.10 Score: 24
# Run [2320] - Total reward: 10742.00 Mean scores: 21.83 Means Scores[:-10]: 22.10 Score: 23
# Run [2330] - Total reward: 11145.00 Mean scores: 21.84 Means Scores[:-10]: 23.20 Score: 24
# Run [2340] - Total reward: 11361.00 Mean scores: 21.84 Means Scores[:-10]: 23.20 Score: 24
# Run [2350] - Total reward: 9693.00 Mean scores: 21.85 Means Scores[:-10]: 22.90 Score: 21
# Run [2360] - Total reward: 10843.00 Mean scores: 21.85 Means Scores[:-10]: 23.00 Score: 23
# Run [2370] - Total reward: 10822.00 Mean scores: 21.86 Means Scores[:-10]: 23.60 Score: 23
# Run [2380] - Total reward: 10815.00 Mean scores: 21.87 Means Scores[:-10]: 23.20 Score: 23
# Run [2390] - Total reward: 10269.00 Mean scores: 21.87 Means Scores[:-10]: 23.20 Score: 22
# Run [2400] - Total reward: 10894.00 Mean scores: 21.88 Means Scores[:-10]: 23.10 Score: 23
# Run [2410] - Total reward: 10901.00 Mean scores: 21.88 Means Scores[:-10]: 23.50 Score: 23
# Run [2420] - Total reward: 9798.00 Mean scores: 21.89 Means Scores[:-10]: 22.80 Score: 21
# Run [2430] - Total reward: 10300.00 Mean scores: 21.89 Means Scores[:-10]: 23.00 Score: 22
# Run [2440] - Total reward: 10679.00 Mean scores: 21.90 Means Scores[:-10]: 23.10 Score: 23
# Run [2450] - Total reward: 9831.00 Mean scores: 21.90 Means Scores[:-10]: 22.60 Score: 21
# Run [2460] - Total reward: 10935.00 Mean scores: 21.91 Means Scores[:-10]: 23.70 Score: 23
# Run [2470] - Total reward: 10359.00 Mean scores: 21.91 Means Scores[:-10]: 23.10 Score: 22
# Run [2480] - Total reward: 10760.00 Mean scores: 21.92 Means Scores[:-10]: 23.50 Score: 23
# Run [2490] - Total reward: 11356.00 Mean scores: 21.92 Means Scores[:-10]: 23.10 Score: 24
# CPU times: user 2h 6min 57s, sys: 17.1 s, total: 2h 7min 14s
# Wall time: 2h 9min 22s

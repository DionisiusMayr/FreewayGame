# %%
import sys
sys.path.append('/content/FreewayGame/leonardo/')
# %matplotlib inline
from collections import defaultdict
from typing import List

import numpy as np
import time
import matplotlib.pyplot as plt
import seaborn as sns

import gym

import src.agents as agents
import src.episode as episode
import src.environment as environment
import src.aux_plots as aux_plots
import src.serializer as serializer

# %%
def print_result(i, scores, total_reward, score):
    if i % 10 == 0:
        print(f"Run [{i:4}] - Total reward: {total_reward:7.2f} Mean scores: {sum(scores) / len(scores):.2f} Means Scores[:-10]: {sum(scores[-10:]) / len(scores[-10:]):5.2f} Score: {score:2} ")

# %%
RAM_mask = [
      14  # Chicken Y
    , 16  # Chicken Lane Collide
    , 108, 109, 110, 111, 112, 113, 114, 115, 116, 117  # Car X Coords
]

# %%
def reduce_state(ob):
    # Doesn't matter where we were hit
    ob[16] = 1 if ob[16] != 255 else 0

    # Reduce chicken y-position
    ob[14] = ob[14] // 3

    for b in range(108, 118):
        # The chicken is in the x-posistion ~49
        if ob[b] < 20 or ob[b] > 80:
            # We don't need to represent cars far from the chicken
            ob[b] = 0
        else:
            # Reduce the cars x-positions sample space
            ob[b] = ob[b] // 3

    return ob
    
def reward_policy(reward, ob, action):
    if reward == 1:
        reward = reward_policy.REWARD_IF_CROSS
    elif ob[16] == 1:  # Collision!
        reward = reward_policy.REWARD_IF_COLISION
    elif action != 1:  # Don't incentivate staying still
        reward = reward_policy.REWARD_IF_STILL

    return reward

def train(agent, env, name, n_runs=5000, n_render=500, n_print=10):
    scores = []
    total_rewards = []
    for i in range(n_runs):
        render = i % n_render == (n_render-1)

        E = defaultdict(lambda: np.zeros(2))

        game_over = False
        state = env.reset()
        state = reduce_state(state)[RAM_mask].data.tobytes()  # Select useful bytes
        action = agent.act(state)

        score = 0
        total_reward = 0

        while not game_over:
            if render:
                time.sleep(0.005)
                env.render()

            old_state = state
            old_action = action
            ob, reward, game_over, _ = env.step(action)

            ob = reduce_state(ob)
            reward = reward_policy(reward, ob, action)

            total_reward += reward

            if reward == reward_policy.REWARD_IF_CROSS:
                score += 1

            state = ob[RAM_mask].data.tobytes()

            action = agent.act(state)  # Next action

            E[old_state][old_action] += 1

            agent.update(old_s=old_state, new_s=state, old_a=old_action, new_a=action, reward=reward, E=i+1)

        scores.append(score)
        total_rewards.append(total_reward)
        
        if i%500 == 499:
        
            exp = serializer.Experiment(agent, scores, total_rewards, reduce_state, reward_policy)
            exp.save_experiment(name)

        if i % n_print == 0:
            print(f"Run [{i:4}] - Total reward: {total_reward:7.2f} Mean scores: {sum(scores) / len(scores):.2f} Means Scores[:-10]: {sum(scores[-10:]) / len(scores[-10:]):5.2f} Score: {score:2} ")
    return scores, total_rewards

# %%
def run_adam_experiment(name, n_runs=2500, AVAILABLE_ACTIONS = 2, GAMMA = 0.99, N0 = 2.5, ALPHA = 0.001,
                        LAMB = 0.0001, REWARD_IF_CROSS=500, REWARD_IF_COLISION=-10, REWARD_IF_STILL=-1):

    env, initial_state = environment.get_env()
    
    reward_policy.REWARD_IF_CROSS = REWARD_IF_CROSS
    reward_policy.REWARD_IF_COLISION = REWARD_IF_COLISION
    reward_policy.REWARD_IF_STILL = REWARD_IF_STILL

    agent = agents.SarsaLFAADAM(gamma=GAMMA, state_size=len(RAM_mask), available_actions=AVAILABLE_ACTIONS, N0=N0, alpha=ALPHA, lamb=LAMB)
    agent.trainScaler(env, RAM_mask)

    
    scores, total_rewards = train(agent, env, name, n_runs=n_runs, n_render=500, n_print=10)
    aux_plots.plot_scores(scores)
    aux_plots.plot_rewards(total_rewards)

# %%
# %%time
run_adam_experiment('adam_r1', N0=2.5, REWARD_IF_CROSS=50, REWARD_IF_COLISION=-1, REWARD_IF_STILL=-0.001)
# Out:
# Run [   0] - Total reward:  529.73 Mean scores: 12.00 Means Scores[:-10]: 12.00 Score: 12
# Run [  10] - Total reward:  573.78 Mean scores: 12.00 Means Scores[:-10]: 12.00 Score: 13
# Run [  20] - Total reward:  634.96 Mean scores: 12.57 Means Scores[:-10]: 13.20 Score: 14
# Run [  30] - Total reward:  747.95 Mean scores: 13.55 Means Scores[:-10]: 15.60 Score: 16
# Run [  40] - Total reward:  673.09 Mean scores: 14.07 Means Scores[:-10]: 15.70 Score: 15
# Run [  50] - Total reward:  899.13 Mean scores: 14.63 Means Scores[:-10]: 16.90 Score: 19
# Run [  60] - Total reward:  745.16 Mean scores: 15.15 Means Scores[:-10]: 17.80 Score: 16
# Run [  70] - Total reward:  790.26 Mean scores: 15.48 Means Scores[:-10]: 17.50 Score: 17
# Run [  80] - Total reward:  784.21 Mean scores: 15.62 Means Scores[:-10]: 16.60 Score: 17
# Run [  90] - Total reward:  723.24 Mean scores: 15.91 Means Scores[:-10]: 18.30 Score: 16
# Run [ 100] - Total reward:  777.27 Mean scores: 16.11 Means Scores[:-10]: 17.90 Score: 17
# Run [ 110] - Total reward: 1043.39 Mean scores: 16.37 Means Scores[:-10]: 19.00 Score: 22
# Run [ 120] - Total reward:  766.40 Mean scores: 16.54 Means Scores[:-10]: 18.40 Score: 17
# Run [ 130] - Total reward:  890.44 Mean scores: 16.76 Means Scores[:-10]: 19.50 Score: 19
# Run [ 140] - Total reward:  949.42 Mean scores: 16.89 Means Scores[:-10]: 18.60 Score: 20
# Run [ 150] - Total reward:  875.54 Mean scores: 17.01 Means Scores[:-10]: 18.70 Score: 19
# Run [ 160] - Total reward:  823.52 Mean scores: 17.13 Means Scores[:-10]: 18.90 Score: 18
# Run [ 170] - Total reward:  942.53 Mean scores: 17.22 Means Scores[:-10]: 18.60 Score: 20
# Run [ 180] - Total reward:  828.56 Mean scores: 17.28 Means Scores[:-10]: 18.30 Score: 18
# Run [ 190] - Total reward:  841.57 Mean scores: 17.37 Means Scores[:-10]: 19.00 Score: 18
# Run [ 200] - Total reward:  826.55 Mean scores: 17.42 Means Scores[:-10]: 18.50 Score: 18
# Run [ 210] - Total reward:  935.54 Mean scores: 17.52 Means Scores[:-10]: 19.40 Score: 20
# Run [ 220] - Total reward:  869.61 Mean scores: 17.57 Means Scores[:-10]: 18.80 Score: 19
# Run [ 230] - Total reward:  887.53 Mean scores: 17.65 Means Scores[:-10]: 19.30 Score: 19
# Run [ 240] - Total reward:  936.66 Mean scores: 17.74 Means Scores[:-10]: 19.80 Score: 20
# Run [ 250] - Total reward:  874.70 Mean scores: 17.78 Means Scores[:-10]: 18.80 Score: 19
# Run [ 260] - Total reward:  926.62 Mean scores: 17.86 Means Scores[:-10]: 19.80 Score: 20
# Run [ 270] - Total reward:  937.69 Mean scores: 17.93 Means Scores[:-10]: 19.80 Score: 20
# Run [ 280] - Total reward: 1042.66 Mean scores: 17.97 Means Scores[:-10]: 19.10 Score: 22
# Run [ 290] - Total reward:  920.64 Mean scores: 18.01 Means Scores[:-10]: 19.10 Score: 20
# Run [ 300] - Total reward:  935.62 Mean scores: 18.08 Means Scores[:-10]: 20.00 Score: 20
# Run [ 310] - Total reward:  870.71 Mean scores: 18.12 Means Scores[:-10]: 19.50 Score: 19
# Run [ 320] - Total reward:  996.67 Mean scores: 18.17 Means Scores[:-10]: 19.50 Score: 21
# Run [ 330] - Total reward:  774.68 Mean scores: 18.18 Means Scores[:-10]: 18.60 Score: 17
# Run [ 340] - Total reward:  972.68 Mean scores: 18.23 Means Scores[:-10]: 20.10 Score: 21
# Run [ 350] - Total reward:  879.67 Mean scores: 18.28 Means Scores[:-10]: 19.70 Score: 19
# Run [ 360] - Total reward:  817.69 Mean scores: 18.34 Means Scores[:-10]: 20.60 Score: 18
# Run [ 370] - Total reward:  931.73 Mean scores: 18.42 Means Scores[:-10]: 21.20 Score: 20
# Run [ 380] - Total reward: 1084.72 Mean scores: 18.47 Means Scores[:-10]: 20.50 Score: 23
# Run [ 390] - Total reward:  982.74 Mean scores: 18.53 Means Scores[:-10]: 20.90 Score: 21
# Run [ 400] - Total reward:  876.72 Mean scores: 18.59 Means Scores[:-10]: 20.80 Score: 19
# Run [ 410] - Total reward:  819.71 Mean scores: 18.64 Means Scores[:-10]: 20.50 Score: 18
# Run [ 420] - Total reward:  982.77 Mean scores: 18.69 Means Scores[:-10]: 20.80 Score: 21
# Run [ 430] - Total reward:  918.75 Mean scores: 18.73 Means Scores[:-10]: 20.30 Score: 20
# Run [ 440] - Total reward:  865.77 Mean scores: 18.77 Means Scores[:-10]: 20.80 Score: 19
# Run [ 450] - Total reward: 1043.70 Mean scores: 18.82 Means Scores[:-10]: 20.90 Score: 22
# Run [ 460] - Total reward:  981.71 Mean scores: 18.88 Means Scores[:-10]: 21.70 Score: 21
# Run [ 470] - Total reward: 1033.74 Mean scores: 18.93 Means Scores[:-10]: 21.00 Score: 22
# Run [ 480] - Total reward: 1153.72 Mean scores: 18.97 Means Scores[:-10]: 21.00 Score: 24
# Run [ 490] - Total reward:  880.74 Mean scores: 19.02 Means Scores[:-10]: 21.20 Score: 19
# Run [ 500] - Total reward: 1036.76 Mean scores: 19.07 Means Scores[:-10]: 21.60 Score: 22
# Run [ 510] - Total reward: 1091.75 Mean scores: 19.13 Means Scores[:-10]: 22.30 Score: 23
# Run [ 520] - Total reward:  977.76 Mean scores: 19.18 Means Scores[:-10]: 21.70 Score: 21
# Run [ 530] - Total reward: 1032.76 Mean scores: 19.23 Means Scores[:-10]: 21.90 Score: 22
# Run [ 540] - Total reward:  978.80 Mean scores: 19.28 Means Scores[:-10]: 21.60 Score: 21
# Run [ 550] - Total reward:  980.78 Mean scores: 19.32 Means Scores[:-10]: 21.60 Score: 21
# Run [ 560] - Total reward: 1148.80 Mean scores: 19.37 Means Scores[:-10]: 22.40 Score: 24
# Run [ 570] - Total reward:  991.83 Mean scores: 19.41 Means Scores[:-10]: 21.60 Score: 21
# Run [ 580] - Total reward:  977.84 Mean scores: 19.45 Means Scores[:-10]: 21.60 Score: 21
# Run [ 590] - Total reward: 1142.76 Mean scores: 19.48 Means Scores[:-10]: 21.40 Score: 24
# Run [ 600] - Total reward: 1094.79 Mean scores: 19.52 Means Scores[:-10]: 21.60 Score: 23
# Run [ 610] - Total reward: 1040.80 Mean scores: 19.55 Means Scores[:-10]: 21.80 Score: 22
# Run [ 620] - Total reward:  971.83 Mean scores: 19.58 Means Scores[:-10]: 21.40 Score: 21
# Run [ 630] - Total reward: 1043.81 Mean scores: 19.61 Means Scores[:-10]: 21.50 Score: 22
# Run [ 640] - Total reward:  984.81 Mean scores: 19.65 Means Scores[:-10]: 22.00 Score: 21
# Run [ 650] - Total reward:  973.84 Mean scores: 19.68 Means Scores[:-10]: 21.70 Score: 21
# Run [ 660] - Total reward: 1040.79 Mean scores: 19.72 Means Scores[:-10]: 22.00 Score: 22
# Run [ 670] - Total reward: 1090.82 Mean scores: 19.76 Means Scores[:-10]: 22.50 Score: 23
# Run [ 680] - Total reward:  980.81 Mean scores: 19.79 Means Scores[:-10]: 21.50 Score: 21
# Run [ 690] - Total reward: 1025.86 Mean scores: 19.82 Means Scores[:-10]: 21.90 Score: 22
# Run [ 700] - Total reward: 1038.79 Mean scores: 19.84 Means Scores[:-10]: 21.80 Score: 22
# Run [ 710] - Total reward: 1089.81 Mean scores: 19.89 Means Scores[:-10]: 23.20 Score: 23
# Run [ 720] - Total reward: 1032.86 Mean scores: 19.92 Means Scores[:-10]: 22.20 Score: 22
# Run [ 730] - Total reward: 1203.80 Mean scores: 19.96 Means Scores[:-10]: 22.60 Score: 25
# Run [ 740] - Total reward: 1081.88 Mean scores: 20.00 Means Scores[:-10]: 23.00 Score: 23
# Run [ 750] - Total reward:  983.84 Mean scores: 20.03 Means Scores[:-10]: 22.40 Score: 21
# Run [ 760] - Total reward: 1089.86 Mean scores: 20.07 Means Scores[:-10]: 23.10 Score: 23
# Run [ 770] - Total reward: 1042.82 Mean scores: 20.11 Means Scores[:-10]: 22.80 Score: 22
# Run [ 780] - Total reward: 1045.88 Mean scores: 20.14 Means Scores[:-10]: 22.20 Score: 22
# Run [ 790] - Total reward: 1041.87 Mean scores: 20.16 Means Scores[:-10]: 22.40 Score: 22
# Run [ 800] - Total reward: 1085.84 Mean scores: 20.19 Means Scores[:-10]: 22.60 Score: 23
# Run [ 810] - Total reward: 1022.87 Mean scores: 20.23 Means Scores[:-10]: 22.90 Score: 22
# Run [ 820] - Total reward: 1143.86 Mean scores: 20.27 Means Scores[:-10]: 23.50 Score: 24
# Run [ 830] - Total reward: 1032.87 Mean scores: 20.30 Means Scores[:-10]: 22.90 Score: 22
# Run [ 840] - Total reward: 1087.89 Mean scores: 20.33 Means Scores[:-10]: 22.80 Score: 23
# Run [ 850] - Total reward: 1147.88 Mean scores: 20.36 Means Scores[:-10]: 22.60 Score: 24
# Run [ 860] - Total reward: 1036.89 Mean scores: 20.39 Means Scores[:-10]: 23.20 Score: 22
# Run [ 870] - Total reward: 1253.87 Mean scores: 20.41 Means Scores[:-10]: 22.40 Score: 26
# Run [ 880] - Total reward: 1042.88 Mean scores: 20.44 Means Scores[:-10]: 22.60 Score: 22
# Run [ 890] - Total reward: 1102.88 Mean scores: 20.47 Means Scores[:-10]: 23.20 Score: 23
# Run [ 900] - Total reward: 1028.90 Mean scores: 20.49 Means Scores[:-10]: 22.80 Score: 22
# Run [ 910] - Total reward: 1082.83 Mean scores: 20.52 Means Scores[:-10]: 23.00 Score: 23
# Run [ 920] - Total reward: 1036.86 Mean scores: 20.54 Means Scores[:-10]: 22.60 Score: 22
# Run [ 930] - Total reward: 1084.90 Mean scores: 20.57 Means Scores[:-10]: 22.90 Score: 23
# Run [ 940] - Total reward: 1027.89 Mean scores: 20.59 Means Scores[:-10]: 22.40 Score: 22
# Run [ 950] - Total reward: 1086.89 Mean scores: 20.61 Means Scores[:-10]: 22.90 Score: 23
# Run [ 960] - Total reward: 1085.90 Mean scores: 20.63 Means Scores[:-10]: 22.70 Score: 23
# Run [ 970] - Total reward: 1139.88 Mean scores: 20.66 Means Scores[:-10]: 22.90 Score: 24
# Run [ 980] - Total reward: 1091.90 Mean scores: 20.68 Means Scores[:-10]: 23.10 Score: 23
# Run [ 990] - Total reward: 1137.89 Mean scores: 20.71 Means Scores[:-10]: 23.00 Score: 24
# Run [1000] - Total reward: 1078.90 Mean scores: 20.72 Means Scores[:-10]: 22.40 Score: 23
# Run [1010] - Total reward: 1150.87 Mean scores: 20.75 Means Scores[:-10]: 23.00 Score: 24
# Run [1020] - Total reward: 1032.90 Mean scores: 20.76 Means Scores[:-10]: 22.40 Score: 22
# Run [1030] - Total reward: 1036.88 Mean scores: 20.78 Means Scores[:-10]: 22.70 Score: 22
# Run [1040] - Total reward: 1195.81 Mean scores: 20.81 Means Scores[:-10]: 23.50 Score: 25
# Run [1050] - Total reward: 1143.90 Mean scores: 20.83 Means Scores[:-10]: 23.70 Score: 24
# Run [1060] - Total reward:  970.90 Mean scores: 20.85 Means Scores[:-10]: 23.00 Score: 21
# Run [1070] - Total reward: 1041.88 Mean scores: 20.88 Means Scores[:-10]: 23.20 Score: 22
# Run [1080] - Total reward: 1150.89 Mean scores: 20.90 Means Scores[:-10]: 23.70 Score: 24
# Run [1090] - Total reward: 1096.89 Mean scores: 20.92 Means Scores[:-10]: 22.50 Score: 23
# Run [1100] - Total reward: 1090.84 Mean scores: 20.93 Means Scores[:-10]: 22.30 Score: 23
# Run [1110] - Total reward:  979.90 Mean scores: 20.95 Means Scores[:-10]: 23.10 Score: 21
# Run [1120] - Total reward: 1032.91 Mean scores: 20.96 Means Scores[:-10]: 22.40 Score: 22
# Run [1130] - Total reward: 1139.89 Mean scores: 20.98 Means Scores[:-10]: 23.10 Score: 24
# Run [1140] - Total reward: 1084.86 Mean scores: 20.99 Means Scores[:-10]: 22.30 Score: 23
# Run [1150] - Total reward:  985.89 Mean scores: 21.01 Means Scores[:-10]: 22.70 Score: 21
# Run [1160] - Total reward: 1130.89 Mean scores: 21.02 Means Scores[:-10]: 23.00 Score: 24
# Run [1170] - Total reward: 1152.87 Mean scores: 21.04 Means Scores[:-10]: 22.60 Score: 24
# Run [1180] - Total reward: 1095.89 Mean scores: 21.06 Means Scores[:-10]: 23.10 Score: 23
# Run [1190] - Total reward: 1151.87 Mean scores: 21.07 Means Scores[:-10]: 22.40 Score: 24
# Run [1200] - Total reward: 1130.90 Mean scores: 21.08 Means Scores[:-10]: 22.70 Score: 24
# Run [1210] - Total reward:  980.91 Mean scores: 21.10 Means Scores[:-10]: 23.30 Score: 21
# Run [1220] - Total reward: 1243.87 Mean scores: 21.12 Means Scores[:-10]: 23.40 Score: 26
# Run [1230] - Total reward: 1137.88 Mean scores: 21.13 Means Scores[:-10]: 23.00 Score: 24
# Run [1240] - Total reward: 1033.88 Mean scores: 21.15 Means Scores[:-10]: 22.90 Score: 22
# Run [1250] - Total reward: 1025.90 Mean scores: 21.16 Means Scores[:-10]: 22.70 Score: 22
# Run [1260] - Total reward: 1082.90 Mean scores: 21.17 Means Scores[:-10]: 22.50 Score: 23
# Run [1270] - Total reward:  992.86 Mean scores: 21.19 Means Scores[:-10]: 23.20 Score: 21
# Run [1280] - Total reward: 1080.90 Mean scores: 21.20 Means Scores[:-10]: 23.20 Score: 23
# Run [1290] - Total reward: 1038.94 Mean scores: 21.22 Means Scores[:-10]: 23.20 Score: 22
# Run [1300] - Total reward: 1089.89 Mean scores: 21.23 Means Scores[:-10]: 23.20 Score: 23
# Run [1310] - Total reward:  963.93 Mean scores: 21.24 Means Scores[:-10]: 22.20 Score: 21
# Run [1320] - Total reward:  980.90 Mean scores: 21.25 Means Scores[:-10]: 22.00 Score: 21
# Run [1330] - Total reward: 1076.91 Mean scores: 21.26 Means Scores[:-10]: 22.70 Score: 23
# Run [1340] - Total reward: 1078.91 Mean scores: 21.27 Means Scores[:-10]: 22.60 Score: 23
# Run [1350] - Total reward: 1138.91 Mean scores: 21.28 Means Scores[:-10]: 23.30 Score: 24
# Run [1360] - Total reward: 1029.90 Mean scores: 21.29 Means Scores[:-10]: 22.30 Score: 22
# Run [1370] - Total reward: 1032.93 Mean scores: 21.30 Means Scores[:-10]: 22.60 Score: 22
# Run [1380] - Total reward: 1036.95 Mean scores: 21.31 Means Scores[:-10]: 22.50 Score: 22
# Run [1390] - Total reward: 1137.94 Mean scores: 21.32 Means Scores[:-10]: 23.20 Score: 24
# Run [1400] - Total reward:  972.91 Mean scores: 21.34 Means Scores[:-10]: 23.50 Score: 21
# Run [1410] - Total reward: 1089.89 Mean scores: 21.35 Means Scores[:-10]: 23.00 Score: 23
# Run [1420] - Total reward: 1072.90 Mean scores: 21.36 Means Scores[:-10]: 22.70 Score: 23
# Run [1430] - Total reward: 1082.93 Mean scores: 21.37 Means Scores[:-10]: 22.50 Score: 23
# Run [1440] - Total reward: 1091.92 Mean scores: 21.38 Means Scores[:-10]: 22.90 Score: 23
# Run [1450] - Total reward:  990.94 Mean scores: 21.38 Means Scores[:-10]: 22.50 Score: 21
# Run [1460] - Total reward: 1036.94 Mean scores: 21.39 Means Scores[:-10]: 22.30 Score: 22
# Run [1470] - Total reward: 1141.91 Mean scores: 21.40 Means Scores[:-10]: 22.90 Score: 24
# Run [1480] - Total reward:  979.96 Mean scores: 21.41 Means Scores[:-10]: 22.40 Score: 21
# Run [1490] - Total reward: 1086.91 Mean scores: 21.42 Means Scores[:-10]: 23.00 Score: 23
# Run [1500] - Total reward: 1082.90 Mean scores: 21.43 Means Scores[:-10]: 22.50 Score: 23
# Run [1510] - Total reward: 1083.92 Mean scores: 21.44 Means Scores[:-10]: 23.00 Score: 23
# Run [1520] - Total reward: 1034.93 Mean scores: 21.44 Means Scores[:-10]: 22.10 Score: 22
# Run [1530] - Total reward: 1083.92 Mean scores: 21.45 Means Scores[:-10]: 22.80 Score: 23
# Run [1540] - Total reward: 1080.94 Mean scores: 21.46 Means Scores[:-10]: 22.50 Score: 23
# Run [1550] - Total reward: 1081.91 Mean scores: 21.46 Means Scores[:-10]: 22.40 Score: 23
# Run [1560] - Total reward:  976.95 Mean scores: 21.47 Means Scores[:-10]: 22.00 Score: 21
# Run [1570] - Total reward: 1135.92 Mean scores: 21.48 Means Scores[:-10]: 23.10 Score: 24
# Run [1580] - Total reward: 1028.95 Mean scores: 21.48 Means Scores[:-10]: 21.60 Score: 22
# Run [1590] - Total reward:  973.93 Mean scores: 21.48 Means Scores[:-10]: 22.50 Score: 21
# Run [1600] - Total reward: 1038.93 Mean scores: 21.49 Means Scores[:-10]: 22.80 Score: 22
# Run [1610] - Total reward: 1031.90 Mean scores: 21.50 Means Scores[:-10]: 22.40 Score: 22
# Run [1620] - Total reward: 1031.91 Mean scores: 21.50 Means Scores[:-10]: 22.30 Score: 22
# Run [1630] - Total reward: 1025.95 Mean scores: 21.51 Means Scores[:-10]: 22.50 Score: 22
# Run [1640] - Total reward:  985.94 Mean scores: 21.51 Means Scores[:-10]: 21.90 Score: 21
# Run [1650] - Total reward: 1028.94 Mean scores: 21.52 Means Scores[:-10]: 22.40 Score: 22
# Run [1660] - Total reward: 1076.89 Mean scores: 21.52 Means Scores[:-10]: 22.80 Score: 23
# Run [1670] - Total reward: 1034.96 Mean scores: 21.53 Means Scores[:-10]: 22.20 Score: 22
# Run [1680] - Total reward: 1134.94 Mean scores: 21.53 Means Scores[:-10]: 22.70 Score: 24
# Run [1690] - Total reward: 1029.94 Mean scores: 21.54 Means Scores[:-10]: 22.20 Score: 22
# Run [1700] - Total reward: 1084.86 Mean scores: 21.54 Means Scores[:-10]: 22.50 Score: 23
# Run [1710] - Total reward: 1141.94 Mean scores: 21.55 Means Scores[:-10]: 22.90 Score: 24
# Run [1720] - Total reward:  930.93 Mean scores: 21.56 Means Scores[:-10]: 22.50 Score: 20
# Run [1730] - Total reward: 1025.94 Mean scores: 21.56 Means Scores[:-10]: 22.10 Score: 22
# Run [1740] - Total reward: 1037.95 Mean scores: 21.56 Means Scores[:-10]: 21.60 Score: 22
# Run [1750] - Total reward: 1031.94 Mean scores: 21.56 Means Scores[:-10]: 21.90 Score: 22
# Run [1760] - Total reward: 1038.93 Mean scores: 21.57 Means Scores[:-10]: 22.30 Score: 22
# Run [1770] - Total reward: 1036.94 Mean scores: 21.57 Means Scores[:-10]: 22.30 Score: 22
# Run [1780] - Total reward: 1038.96 Mean scores: 21.58 Means Scores[:-10]: 22.50 Score: 22
# Run [1790] - Total reward: 1200.89 Mean scores: 21.58 Means Scores[:-10]: 22.40 Score: 25
# Run [1800] - Total reward: 1147.94 Mean scores: 21.59 Means Scores[:-10]: 22.70 Score: 24
# Run [1810] - Total reward: 1081.97 Mean scores: 21.60 Means Scores[:-10]: 23.00 Score: 23
# Run [1820] - Total reward: 1092.93 Mean scores: 21.60 Means Scores[:-10]: 21.80 Score: 23
# Run [1830] - Total reward: 1088.91 Mean scores: 21.60 Means Scores[:-10]: 21.90 Score: 23
# Run [1840] - Total reward: 1076.93 Mean scores: 21.60 Means Scores[:-10]: 22.60 Score: 23
# Run [1850] - Total reward: 1033.94 Mean scores: 21.61 Means Scores[:-10]: 22.40 Score: 22
# Run [1860] - Total reward: 1149.94 Mean scores: 21.61 Means Scores[:-10]: 22.70 Score: 24
# Run [1870] - Total reward: 1026.93 Mean scores: 21.62 Means Scores[:-10]: 22.90 Score: 22
# Run [1880] - Total reward: 1034.94 Mean scores: 21.63 Means Scores[:-10]: 22.60 Score: 22
# Run [1890] - Total reward: 1091.92 Mean scores: 21.63 Means Scores[:-10]: 22.20 Score: 23
# Run [1900] - Total reward: 1030.96 Mean scores: 21.63 Means Scores[:-10]: 22.80 Score: 22
# Run [1910] - Total reward: 1039.96 Mean scores: 21.64 Means Scores[:-10]: 22.60 Score: 22
# Run [1920] - Total reward: 1090.91 Mean scores: 21.64 Means Scores[:-10]: 22.40 Score: 23
# Run [1930] - Total reward: 1033.96 Mean scores: 21.65 Means Scores[:-10]: 23.00 Score: 22
# Run [1940] - Total reward: 1080.90 Mean scores: 21.65 Means Scores[:-10]: 22.40 Score: 23
# Run [1950] - Total reward: 1038.95 Mean scores: 21.66 Means Scores[:-10]: 22.40 Score: 22
# Run [1960] - Total reward: 1085.92 Mean scores: 21.66 Means Scores[:-10]: 22.90 Score: 23
# Run [1970] - Total reward: 1094.96 Mean scores: 21.67 Means Scores[:-10]: 23.20 Score: 23
# Run [1980] - Total reward:  973.96 Mean scores: 21.67 Means Scores[:-10]: 22.00 Score: 21
# Run [1990] - Total reward: 1084.95 Mean scores: 21.68 Means Scores[:-10]: 22.20 Score: 23
# Run [2000] - Total reward: 1031.94 Mean scores: 21.68 Means Scores[:-10]: 21.70 Score: 22
# Run [2010] - Total reward: 1029.93 Mean scores: 21.69 Means Scores[:-10]: 23.30 Score: 22
# Run [2020] - Total reward: 1085.96 Mean scores: 21.69 Means Scores[:-10]: 22.70 Score: 23
# Run [2030] - Total reward: 1184.93 Mean scores: 21.70 Means Scores[:-10]: 22.80 Score: 25
# Run [2040] - Total reward: 1089.95 Mean scores: 21.70 Means Scores[:-10]: 22.40 Score: 23
# Run [2050] - Total reward: 1093.94 Mean scores: 21.70 Means Scores[:-10]: 22.70 Score: 23
# Run [2060] - Total reward: 1091.94 Mean scores: 21.71 Means Scores[:-10]: 22.80 Score: 23
# Run [2070] - Total reward: 1093.92 Mean scores: 21.72 Means Scores[:-10]: 23.40 Score: 23
# Run [2080] - Total reward: 1039.97 Mean scores: 21.72 Means Scores[:-10]: 22.80 Score: 22
# Run [2090] - Total reward: 1034.94 Mean scores: 21.73 Means Scores[:-10]: 22.50 Score: 22
# Run [2100] - Total reward: 1091.95 Mean scores: 21.73 Means Scores[:-10]: 23.20 Score: 23
# Run [2110] - Total reward: 1025.95 Mean scores: 21.74 Means Scores[:-10]: 22.90 Score: 22
# Run [2120] - Total reward: 1128.95 Mean scores: 21.74 Means Scores[:-10]: 22.80 Score: 24
# Run [2130] - Total reward: 1142.94 Mean scores: 21.75 Means Scores[:-10]: 23.10 Score: 24
# Run [2140] - Total reward: 1080.91 Mean scores: 21.76 Means Scores[:-10]: 23.60 Score: 23
# Run [2150] - Total reward: 1026.96 Mean scores: 21.77 Means Scores[:-10]: 23.20 Score: 22
# Run [2160] - Total reward: 1034.95 Mean scores: 21.77 Means Scores[:-10]: 22.90 Score: 22
# Run [2170] - Total reward: 1035.98 Mean scores: 21.78 Means Scores[:-10]: 23.70 Score: 22
# Run [2180] - Total reward: 1128.94 Mean scores: 21.78 Means Scores[:-10]: 22.80 Score: 24
# Run [2190] - Total reward: 1135.92 Mean scores: 21.79 Means Scores[:-10]: 22.70 Score: 24
# Run [2200] - Total reward: 1086.94 Mean scores: 21.79 Means Scores[:-10]: 22.80 Score: 23
# Run [2210] - Total reward: 1081.98 Mean scores: 21.80 Means Scores[:-10]: 22.70 Score: 23
# Run [2220] - Total reward: 1023.95 Mean scores: 21.80 Means Scores[:-10]: 22.80 Score: 22
# Run [2230] - Total reward: 1077.96 Mean scores: 21.81 Means Scores[:-10]: 22.60 Score: 23
# Run [2240] - Total reward: 1080.96 Mean scores: 21.81 Means Scores[:-10]: 22.90 Score: 23
# Run [2250] - Total reward: 1136.95 Mean scores: 21.81 Means Scores[:-10]: 22.60 Score: 24
# Run [2260] - Total reward:  967.96 Mean scores: 21.82 Means Scores[:-10]: 22.70 Score: 21
# Run [2270] - Total reward: 1090.97 Mean scores: 21.82 Means Scores[:-10]: 23.10 Score: 23
# Run [2280] - Total reward: 1299.94 Mean scores: 21.83 Means Scores[:-10]: 23.20 Score: 27
# Run [2290] - Total reward: 1081.93 Mean scores: 21.83 Means Scores[:-10]: 22.60 Score: 23
# Run [2300] - Total reward:  985.96 Mean scores: 21.84 Means Scores[:-10]: 22.70 Score: 21
# Run [2310] - Total reward: 1028.97 Mean scores: 21.84 Means Scores[:-10]: 23.60 Score: 22
# Run [2320] - Total reward: 1039.96 Mean scores: 21.85 Means Scores[:-10]: 22.90 Score: 22
# Run [2330] - Total reward: 1029.95 Mean scores: 21.85 Means Scores[:-10]: 22.60 Score: 22
# Run [2340] - Total reward: 1081.95 Mean scores: 21.86 Means Scores[:-10]: 23.30 Score: 23
# Run [2350] - Total reward: 1020.96 Mean scores: 21.86 Means Scores[:-10]: 22.90 Score: 22
# Run [2360] - Total reward: 1089.95 Mean scores: 21.86 Means Scores[:-10]: 22.10 Score: 23
# Run [2370] - Total reward: 1134.96 Mean scores: 21.87 Means Scores[:-10]: 22.50 Score: 24
# Run [2380] - Total reward: 1136.94 Mean scores: 21.87 Means Scores[:-10]: 22.90 Score: 24
# Run [2390] - Total reward: 1035.96 Mean scores: 21.88 Means Scores[:-10]: 23.10 Score: 22
# Run [2400] - Total reward: 1075.94 Mean scores: 21.88 Means Scores[:-10]: 22.50 Score: 23
# Run [2410] - Total reward: 1146.96 Mean scores: 21.88 Means Scores[:-10]: 22.90 Score: 24
# Run [2420] - Total reward: 1040.97 Mean scores: 21.89 Means Scores[:-10]: 22.60 Score: 22
# Run [2430] - Total reward:  978.96 Mean scores: 21.89 Means Scores[:-10]: 22.90 Score: 21
# Run [2440] - Total reward: 1032.96 Mean scores: 21.89 Means Scores[:-10]: 22.40 Score: 22
# Run [2450] - Total reward: 1197.97 Mean scores: 21.90 Means Scores[:-10]: 23.00 Score: 25
# Run [2460] - Total reward: 1140.95 Mean scores: 21.90 Means Scores[:-10]: 23.30 Score: 24
# Run [2470] - Total reward: 1128.96 Mean scores: 21.91 Means Scores[:-10]: 23.20 Score: 24
# Run [2480] - Total reward: 1018.95 Mean scores: 21.91 Means Scores[:-10]: 22.80 Score: 22
# Run [2490] - Total reward:  965.97 Mean scores: 21.91 Means Scores[:-10]: 22.30 Score: 21
# CPU times: user 2h 5min, sys: 11.1 s, total: 2h 5min 11s
# Wall time: 2h 6min 59s

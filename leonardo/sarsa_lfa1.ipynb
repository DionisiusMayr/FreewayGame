# %%
import sys
sys.path.append('/content/FreewayGame/leonardo/')
# %matplotlib inline
from collections import defaultdict
from typing import List

import numpy as np
import time
import matplotlib.pyplot as plt
import seaborn as sns

import gym

import src.agents as agents
import src.episode as episode
import src.environment as environment
import src.aux_plots as aux_plots
import src.serializer as serializer

# %%
def print_result(i, scores, total_reward, score):
    if i % 10 == 0:
        print(f"Run [{i:4}] - Total reward: {total_reward:7.2f} Mean scores: {sum(scores) / len(scores):.2f} Means Scores[:-10]: {sum(scores[-10:]) / len(scores[-10:]):5.2f} Score: {score:2} ")

# %%
RAM_mask = [
      14  # Chicken Y
    , 16  # Chicken Lane Collide
    , 108, 109, 110, 111, 112, 113, 114, 115, 116, 117  # Car X Coords
]

# %%
def reduce_state(ob):
    # Doesn't matter where we were hit
    ob[16] = 1 if ob[16] != 255 else 0

    # Reduce chicken y-position
    ob[14] = ob[14] // 3

    for b in range(108, 118):
        # The chicken is in the x-posistion ~49
        if ob[b] < 20 or ob[b] > 80:
            # We don't need to represent cars far from the chicken
            ob[b] = 0
        else:
            # Reduce the cars x-positions sample space
            ob[b] = ob[b] // 3

    return ob
    
def reward_policy(reward, ob, action):
    if reward == 1:
        reward = reward_policy.REWARD_IF_CROSS
    elif ob[16] == 1:  # Collision!
        reward = reward_policy.REWARD_IF_COLISION
    elif action != 1:  # Don't incentivate staying still
        reward = reward_policy.REWARD_IF_STILL

    return reward

def train(agent, env, name, n_runs=5000, n_render=500, n_print=10):
    scores = []
    total_rewards = []
    for i in range(n_runs):
        render = i % n_render == (n_render-1)

        E = defaultdict(lambda: np.zeros(2))

        game_over = False
        state = env.reset()
        state = reduce_state(state)[RAM_mask].data.tobytes()  # Select useful bytes
        action = agent.act(state)

        score = 0
        total_reward = 0

        while not game_over:
            if render:
                time.sleep(0.005)
                env.render()

            old_state = state
            old_action = action
            ob, reward, game_over, _ = env.step(action)

            ob = reduce_state(ob)
            reward = reward_policy(reward, ob, action)

            total_reward += reward

            if reward == reward_policy.REWARD_IF_CROSS:
                score += 1

            state = ob[RAM_mask].data.tobytes()

            action = agent.act(state)  # Next action

            E[old_state][old_action] += 1

            agent.update(old_s=old_state, new_s=state, old_a=old_action, new_a=action, reward=reward, E=i+1)

        scores.append(score)
        total_rewards.append(total_reward)
        
        if i%500 == 499:
        
            exp = serializer.Experiment(agent, scores, total_rewards, reduce_state, reward_policy)
            exp.save_experiment(name)

        if i % n_print == 0:
            print(f"Run [{i:4}] - Total reward: {total_reward:7.2f} Mean scores: {sum(scores) / len(scores):.2f} Means Scores[:-10]: {sum(scores[-10:]) / len(scores[-10:]):5.2f} Score: {score:2} ")
    return scores, total_rewards

# %%
def run_lfa_experiment(name, n_runs=2500, AVAILABLE_ACTIONS = 2, GAMMA = 0.99, N0 = 2.5, ALPHA = 0.001,
                        LAMB = 0.0, REWARD_IF_CROSS=500, REWARD_IF_COLISION=-10, REWARD_IF_STILL=-1):

    env, initial_state = environment.get_env()
    
    reward_policy.REWARD_IF_CROSS = REWARD_IF_CROSS
    reward_policy.REWARD_IF_COLISION = REWARD_IF_COLISION
    reward_policy.REWARD_IF_STILL = REWARD_IF_STILL

    agent = agents.SarsaLFA(gamma=GAMMA, state_size=len(RAM_mask), available_actions=AVAILABLE_ACTIONS, N0=N0, alpha=ALPHA, lamb=LAMB)
    agent.trainScaler(env, RAM_mask)
    
    scores, total_rewards = train(agent, env, name, n_runs=n_runs, n_render=500, n_print=10)
    aux_plots.plot_scores(scores)
    aux_plots.plot_rewards(total_rewards)

# %%
# %%time
run_lfa_experiment('sarsa_lfa_n00', N0=0.001)
# Out:
# Run [   0] - Total reward: 3551.00 Mean scores: 11.00 Means Scores[:-10]: 11.00 Score: 11
# Run [  10] - Total reward: 7491.00 Mean scores: 13.82 Means Scores[:-10]: 14.10 Score: 18
# Run [  20] - Total reward: 8802.00 Mean scores: 15.95 Means Scores[:-10]: 18.30 Score: 20
# Run [  30] - Total reward: 7810.00 Mean scores: 17.03 Means Scores[:-10]: 19.30 Score: 18
# Run [  40] - Total reward: 8966.00 Mean scores: 17.51 Means Scores[:-10]: 19.00 Score: 20
# Run [  50] - Total reward: 8092.00 Mean scores: 17.80 Means Scores[:-10]: 19.00 Score: 18
# Run [  60] - Total reward: 10093.00 Mean scores: 18.21 Means Scores[:-10]: 20.30 Score: 22
# Run [  70] - Total reward: 9049.00 Mean scores: 18.66 Means Scores[:-10]: 21.40 Score: 20
# Run [  80] - Total reward: 10763.00 Mean scores: 18.99 Means Scores[:-10]: 21.30 Score: 23
# Run [  90] - Total reward: 10320.00 Mean scores: 19.36 Means Scores[:-10]: 22.40 Score: 22
# Run [ 100] - Total reward: 10655.00 Mean scores: 19.70 Means Scores[:-10]: 22.80 Score: 23
# Run [ 110] - Total reward: 10297.00 Mean scores: 19.98 Means Scores[:-10]: 22.80 Score: 22
# Run [ 120] - Total reward: 10239.00 Mean scores: 20.20 Means Scores[:-10]: 22.60 Score: 22
# Run [ 130] - Total reward: 11312.00 Mean scores: 20.42 Means Scores[:-10]: 23.10 Score: 24
# Run [ 140] - Total reward: 11341.00 Mean scores: 20.62 Means Scores[:-10]: 23.20 Score: 24
# Run [ 150] - Total reward: 11278.00 Mean scores: 20.78 Means Scores[:-10]: 23.10 Score: 24
# Run [ 160] - Total reward: 10206.00 Mean scores: 20.91 Means Scores[:-10]: 22.90 Score: 22
# Run [ 170] - Total reward: 10790.00 Mean scores: 20.99 Means Scores[:-10]: 22.30 Score: 23
# Run [ 180] - Total reward: 11402.00 Mean scores: 21.12 Means Scores[:-10]: 23.20 Score: 24
# Run [ 190] - Total reward: 10831.00 Mean scores: 21.21 Means Scores[:-10]: 23.00 Score: 23
# Run [ 200] - Total reward: 11398.00 Mean scores: 21.30 Means Scores[:-10]: 23.00 Score: 24
# Run [ 210] - Total reward: 10918.00 Mean scores: 21.37 Means Scores[:-10]: 22.80 Score: 23
# Run [ 220] - Total reward: 11308.00 Mean scores: 21.43 Means Scores[:-10]: 22.50 Score: 24
# Run [ 230] - Total reward: 9634.00 Mean scores: 21.49 Means Scores[:-10]: 23.00 Score: 21
# Run [ 240] - Total reward: 10778.00 Mean scores: 21.56 Means Scores[:-10]: 23.10 Score: 23
# Run [ 250] - Total reward: 11358.00 Mean scores: 21.63 Means Scores[:-10]: 23.30 Score: 24
# Run [ 260] - Total reward: 10207.00 Mean scores: 21.69 Means Scores[:-10]: 23.10 Score: 22
# Run [ 270] - Total reward: 10167.00 Mean scores: 21.70 Means Scores[:-10]: 22.20 Score: 22
# Run [ 280] - Total reward: 10886.00 Mean scores: 21.74 Means Scores[:-10]: 22.70 Score: 23
# Run [ 290] - Total reward: 9657.00 Mean scores: 21.76 Means Scores[:-10]: 22.30 Score: 21
# Run [ 300] - Total reward: 9777.00 Mean scores: 21.76 Means Scores[:-10]: 21.80 Score: 21
# Run [ 310] - Total reward: 9773.00 Mean scores: 21.75 Means Scores[:-10]: 21.30 Score: 21
# Run [ 320] - Total reward: 11248.00 Mean scores: 21.74 Means Scores[:-10]: 21.70 Score: 24
# Run [ 330] - Total reward: 10294.00 Mean scores: 21.76 Means Scores[:-10]: 22.20 Score: 22
# Run [ 340] - Total reward: 9870.00 Mean scores: 21.76 Means Scores[:-10]: 21.90 Score: 21
# Run [ 350] - Total reward: 9800.00 Mean scores: 21.74 Means Scores[:-10]: 21.00 Score: 21
# Run [ 360] - Total reward: 9820.00 Mean scores: 21.73 Means Scores[:-10]: 21.20 Score: 21
# Run [ 370] - Total reward: 9790.00 Mean scores: 21.73 Means Scores[:-10]: 21.90 Score: 21
# Run [ 380] - Total reward: 9790.00 Mean scores: 21.75 Means Scores[:-10]: 22.50 Score: 21
# Run [ 390] - Total reward: 9720.00 Mean scores: 21.77 Means Scores[:-10]: 22.50 Score: 21
# Run [ 400] - Total reward: 10130.00 Mean scores: 21.77 Means Scores[:-10]: 21.70 Score: 22
# Run [ 410] - Total reward: 9820.00 Mean scores: 21.75 Means Scores[:-10]: 21.00 Score: 21
# Run [ 420] - Total reward: 9810.00 Mean scores: 21.74 Means Scores[:-10]: 21.50 Score: 21
# Run [ 430] - Total reward: 9790.00 Mean scores: 21.74 Means Scores[:-10]: 21.60 Score: 21
# Run [ 440] - Total reward: 11308.00 Mean scores: 21.74 Means Scores[:-10]: 21.80 Score: 24
# Run [ 450] - Total reward: 11306.00 Mean scores: 21.75 Means Scores[:-10]: 21.90 Score: 24
# Run [ 460] - Total reward: 11305.00 Mean scores: 21.75 Means Scores[:-10]: 22.00 Score: 24
# Run [ 470] - Total reward: 9740.00 Mean scores: 21.75 Means Scores[:-10]: 21.70 Score: 21
# Run [ 480] - Total reward: 9800.00 Mean scores: 21.74 Means Scores[:-10]: 21.50 Score: 21
# Run [ 490] - Total reward: 10765.00 Mean scores: 21.74 Means Scores[:-10]: 21.40 Score: 23
# Run [ 500] - Total reward: 9760.00 Mean scores: 21.73 Means Scores[:-10]: 21.40 Score: 21
# Run [ 510] - Total reward: 11389.00 Mean scores: 21.72 Means Scores[:-10]: 21.40 Score: 24
# Run [ 520] - Total reward: 9790.00 Mean scores: 21.72 Means Scores[:-10]: 21.40 Score: 21
# Run [ 530] - Total reward: 9760.00 Mean scores: 21.71 Means Scores[:-10]: 21.40 Score: 21
# Run [ 540] - Total reward: 9780.00 Mean scores: 21.71 Means Scores[:-10]: 21.60 Score: 21
# Run [ 550] - Total reward: 10819.00 Mean scores: 21.71 Means Scores[:-10]: 21.60 Score: 23
# Run [ 560] - Total reward: 9730.00 Mean scores: 21.70 Means Scores[:-10]: 21.20 Score: 21
# Run [ 570] - Total reward: 9810.00 Mean scores: 21.69 Means Scores[:-10]: 21.00 Score: 21
# Run [ 580] - Total reward: 9820.00 Mean scores: 21.69 Means Scores[:-10]: 21.70 Score: 21
# Run [ 590] - Total reward: 9810.00 Mean scores: 21.68 Means Scores[:-10]: 21.20 Score: 21
# Run [ 600] - Total reward: 9780.00 Mean scores: 21.67 Means Scores[:-10]: 21.20 Score: 21
# Run [ 610] - Total reward: 9790.00 Mean scores: 21.67 Means Scores[:-10]: 21.50 Score: 21
# Run [ 620] - Total reward: 9760.00 Mean scores: 21.67 Means Scores[:-10]: 21.80 Score: 21
# Run [ 630] - Total reward: 9830.00 Mean scores: 21.67 Means Scores[:-10]: 21.80 Score: 21
# Run [ 640] - Total reward: 10800.00 Mean scores: 21.67 Means Scores[:-10]: 21.80 Score: 23
# Run [ 650] - Total reward: 9830.00 Mean scores: 21.66 Means Scores[:-10]: 21.00 Score: 21
# Run [ 660] - Total reward: 9830.00 Mean scores: 21.66 Means Scores[:-10]: 21.60 Score: 21
# Run [ 670] - Total reward: 9760.00 Mean scores: 21.66 Means Scores[:-10]: 21.40 Score: 21
# Run [ 680] - Total reward: 10910.00 Mean scores: 21.66 Means Scores[:-10]: 21.60 Score: 23
# Run [ 690] - Total reward: 9800.00 Mean scores: 21.65 Means Scores[:-10]: 21.20 Score: 21
# Run [ 700] - Total reward: 9790.00 Mean scores: 21.64 Means Scores[:-10]: 21.20 Score: 21
# Run [ 710] - Total reward: 9830.00 Mean scores: 21.64 Means Scores[:-10]: 21.00 Score: 21
# Run [ 720] - Total reward: 10810.00 Mean scores: 21.64 Means Scores[:-10]: 21.60 Score: 23
# Run [ 730] - Total reward: 9780.00 Mean scores: 21.63 Means Scores[:-10]: 21.40 Score: 21
# Run [ 740] - Total reward: 9710.00 Mean scores: 21.62 Means Scores[:-10]: 21.00 Score: 21
# Run [ 750] - Total reward: 9760.00 Mean scores: 21.63 Means Scores[:-10]: 22.00 Score: 21
# Run [ 760] - Total reward: 9820.00 Mean scores: 21.63 Means Scores[:-10]: 21.60 Score: 21
# Run [ 770] - Total reward: 9730.00 Mean scores: 21.63 Means Scores[:-10]: 21.40 Score: 21
# Run [ 780] - Total reward: 9770.00 Mean scores: 21.62 Means Scores[:-10]: 21.20 Score: 21
# Run [ 790] - Total reward: 9730.00 Mean scores: 21.62 Means Scores[:-10]: 21.40 Score: 21
# Run [ 800] - Total reward: 9840.00 Mean scores: 21.62 Means Scores[:-10]: 21.60 Score: 21
# Run [ 810] - Total reward: 9810.00 Mean scores: 21.62 Means Scores[:-10]: 21.60 Score: 21
# Run [ 820] - Total reward: 9770.00 Mean scores: 21.62 Means Scores[:-10]: 21.60 Score: 21
# Run [ 830] - Total reward: 9820.00 Mean scores: 21.61 Means Scores[:-10]: 21.30 Score: 21
# Run [ 840] - Total reward: 10840.00 Mean scores: 21.61 Means Scores[:-10]: 21.20 Score: 23
# Run [ 850] - Total reward: 9780.00 Mean scores: 21.61 Means Scores[:-10]: 21.40 Score: 21
# Run [ 860] - Total reward: 9790.00 Mean scores: 21.60 Means Scores[:-10]: 21.20 Score: 21
# Run [ 870] - Total reward: 9790.00 Mean scores: 21.60 Means Scores[:-10]: 21.60 Score: 21
# Run [ 880] - Total reward: 9750.00 Mean scores: 21.60 Means Scores[:-10]: 21.60 Score: 21
# Run [ 890] - Total reward: 9830.00 Mean scores: 21.60 Means Scores[:-10]: 21.60 Score: 21
# Run [ 900] - Total reward: 9810.00 Mean scores: 21.60 Means Scores[:-10]: 21.40 Score: 21
# Run [ 910] - Total reward: 9730.00 Mean scores: 21.60 Means Scores[:-10]: 21.60 Score: 21
# Run [ 920] - Total reward: 9830.00 Mean scores: 21.60 Means Scores[:-10]: 21.50 Score: 21
# Run [ 930] - Total reward: 9820.00 Mean scores: 21.59 Means Scores[:-10]: 21.20 Score: 21
# Run [ 940] - Total reward: 10880.00 Mean scores: 21.59 Means Scores[:-10]: 21.40 Score: 23
# Run [ 950] - Total reward: 9790.00 Mean scores: 21.59 Means Scores[:-10]: 21.40 Score: 21
# Run [ 960] - Total reward: 9730.00 Mean scores: 21.59 Means Scores[:-10]: 21.40 Score: 21
# Run [ 970] - Total reward: 9800.00 Mean scores: 21.58 Means Scores[:-10]: 21.20 Score: 21
# Run [ 980] - Total reward: 9780.00 Mean scores: 21.58 Means Scores[:-10]: 21.20 Score: 21
# Run [ 990] - Total reward: 9820.00 Mean scores: 21.58 Means Scores[:-10]: 21.60 Score: 21
# Run [1000] - Total reward: 10840.00 Mean scores: 21.58 Means Scores[:-10]: 21.80 Score: 23
# Run [1010] - Total reward: 9820.00 Mean scores: 21.58 Means Scores[:-10]: 21.40 Score: 21
# Run [1020] - Total reward: 9830.00 Mean scores: 21.58 Means Scores[:-10]: 21.60 Score: 21
# Run [1030] - Total reward: 9790.00 Mean scores: 21.58 Means Scores[:-10]: 21.40 Score: 21
# Run [1040] - Total reward: 10850.00 Mean scores: 21.58 Means Scores[:-10]: 21.60 Score: 23
# Run [1050] - Total reward: 9780.00 Mean scores: 21.58 Means Scores[:-10]: 21.60 Score: 21
# Run [1060] - Total reward: 9800.00 Mean scores: 21.58 Means Scores[:-10]: 21.60 Score: 21
# Run [1070] - Total reward: 10790.00 Mean scores: 21.58 Means Scores[:-10]: 21.60 Score: 23
# Run [1080] - Total reward: 9740.00 Mean scores: 21.57 Means Scores[:-10]: 21.10 Score: 21
# Run [1090] - Total reward: 9790.00 Mean scores: 21.57 Means Scores[:-10]: 21.50 Score: 21
# Run [1100] - Total reward: 9750.00 Mean scores: 21.57 Means Scores[:-10]: 21.40 Score: 21
# Run [1110] - Total reward: 9820.00 Mean scores: 21.57 Means Scores[:-10]: 21.00 Score: 21
# Run [1120] - Total reward: 10880.00 Mean scores: 21.57 Means Scores[:-10]: 21.40 Score: 23
# Run [1130] - Total reward: 10840.00 Mean scores: 21.57 Means Scores[:-10]: 21.60 Score: 23
# Run [1140] - Total reward: 9780.00 Mean scores: 21.57 Means Scores[:-10]: 21.60 Score: 21
# Run [1150] - Total reward: 9830.00 Mean scores: 21.56 Means Scores[:-10]: 21.20 Score: 21
# Run [1160] - Total reward: 9860.00 Mean scores: 21.56 Means Scores[:-10]: 21.20 Score: 21
# Run [1170] - Total reward: 10880.00 Mean scores: 21.57 Means Scores[:-10]: 22.20 Score: 23
# Run [1180] - Total reward: 9770.00 Mean scores: 21.56 Means Scores[:-10]: 21.20 Score: 21
# Run [1190] - Total reward: 9800.00 Mean scores: 21.56 Means Scores[:-10]: 21.40 Score: 21
# Run [1200] - Total reward: 9810.00 Mean scores: 21.56 Means Scores[:-10]: 21.20 Score: 21
# Run [1210] - Total reward: 9780.00 Mean scores: 21.55 Means Scores[:-10]: 21.00 Score: 21
# Run [1220] - Total reward: 9840.00 Mean scores: 21.55 Means Scores[:-10]: 21.40 Score: 21
# Run [1230] - Total reward: 9810.00 Mean scores: 21.55 Means Scores[:-10]: 21.00 Score: 21
# Run [1240] - Total reward: 9780.00 Mean scores: 21.55 Means Scores[:-10]: 21.40 Score: 21
# Run [1250] - Total reward: 9800.00 Mean scores: 21.55 Means Scores[:-10]: 21.40 Score: 21
# Run [1260] - Total reward: 9780.00 Mean scores: 21.55 Means Scores[:-10]: 22.20 Score: 21
# Run [1270] - Total reward: 10820.00 Mean scores: 21.55 Means Scores[:-10]: 21.80 Score: 23
# Run [1280] - Total reward: 9830.00 Mean scores: 21.55 Means Scores[:-10]: 21.60 Score: 21
# Run [1290] - Total reward: 10810.00 Mean scores: 21.55 Means Scores[:-10]: 21.50 Score: 23
# Run [1300] - Total reward: 10870.00 Mean scores: 21.55 Means Scores[:-10]: 21.60 Score: 23
# Run [1310] - Total reward: 9720.00 Mean scores: 21.55 Means Scores[:-10]: 21.20 Score: 21
# Run [1320] - Total reward: 9740.00 Mean scores: 21.55 Means Scores[:-10]: 21.20 Score: 21
# Run [1330] - Total reward: 9770.00 Mean scores: 21.54 Means Scores[:-10]: 21.00 Score: 21
# Run [1340] - Total reward: 9770.00 Mean scores: 21.55 Means Scores[:-10]: 22.10 Score: 21
# Run [1350] - Total reward: 9850.00 Mean scores: 21.55 Means Scores[:-10]: 21.40 Score: 21
# Run [1360] - Total reward: 9770.00 Mean scores: 21.55 Means Scores[:-10]: 21.40 Score: 21
# Run [1370] - Total reward: 9710.00 Mean scores: 21.55 Means Scores[:-10]: 21.60 Score: 21
# Run [1380] - Total reward: 9880.00 Mean scores: 21.54 Means Scores[:-10]: 21.40 Score: 21
# Run [1390] - Total reward: 10810.00 Mean scores: 21.54 Means Scores[:-10]: 21.60 Score: 23
# Run [1400] - Total reward: 10840.00 Mean scores: 21.55 Means Scores[:-10]: 21.80 Score: 23
# Run [1410] - Total reward: 11856.00 Mean scores: 21.55 Means Scores[:-10]: 22.00 Score: 25
# Run [1420] - Total reward: 10790.00 Mean scores: 21.55 Means Scores[:-10]: 21.80 Score: 23
# Run [1430] - Total reward: 9820.00 Mean scores: 21.55 Means Scores[:-10]: 21.00 Score: 21
# Run [1440] - Total reward: 9780.00 Mean scores: 21.55 Means Scores[:-10]: 21.20 Score: 21
# Run [1450] - Total reward: 9810.00 Mean scores: 21.54 Means Scores[:-10]: 21.40 Score: 21
# Run [1460] - Total reward: 9740.00 Mean scores: 21.54 Means Scores[:-10]: 21.40 Score: 21
# Run [1470] - Total reward: 10870.00 Mean scores: 21.54 Means Scores[:-10]: 21.20 Score: 23
# Run [1480] - Total reward: 10326.00 Mean scores: 21.54 Means Scores[:-10]: 21.50 Score: 22
# Run [1490] - Total reward: 9800.00 Mean scores: 21.54 Means Scores[:-10]: 21.20 Score: 21
# Run [1500] - Total reward: 9830.00 Mean scores: 21.54 Means Scores[:-10]: 22.00 Score: 21
# Run [1510] - Total reward: 9780.00 Mean scores: 21.54 Means Scores[:-10]: 21.20 Score: 21
# Run [1520] - Total reward: 10850.00 Mean scores: 21.54 Means Scores[:-10]: 21.20 Score: 23
# Run [1530] - Total reward: 9770.00 Mean scores: 21.54 Means Scores[:-10]: 21.40 Score: 21
# Run [1540] - Total reward: 9850.00 Mean scores: 21.54 Means Scores[:-10]: 21.40 Score: 21
# Run [1550] - Total reward: 9790.00 Mean scores: 21.54 Means Scores[:-10]: 21.60 Score: 21
# Run [1560] - Total reward: 9780.00 Mean scores: 21.53 Means Scores[:-10]: 21.00 Score: 21
# Run [1570] - Total reward: 9790.00 Mean scores: 21.53 Means Scores[:-10]: 21.40 Score: 21
# Run [1580] - Total reward: 9870.00 Mean scores: 21.53 Means Scores[:-10]: 21.20 Score: 21
# Run [1590] - Total reward: 10850.00 Mean scores: 21.53 Means Scores[:-10]: 22.00 Score: 23
# Run [1600] - Total reward: 9720.00 Mean scores: 21.53 Means Scores[:-10]: 21.40 Score: 21
# Run [1610] - Total reward: 9780.00 Mean scores: 21.53 Means Scores[:-10]: 21.20 Score: 21
# Run [1620] - Total reward: 10870.00 Mean scores: 21.53 Means Scores[:-10]: 21.40 Score: 23
# Run [1630] - Total reward: 9750.00 Mean scores: 21.53 Means Scores[:-10]: 21.40 Score: 21
# Run [1640] - Total reward: 10790.00 Mean scores: 21.53 Means Scores[:-10]: 21.60 Score: 23
# Run [1650] - Total reward: 10840.00 Mean scores: 21.53 Means Scores[:-10]: 21.20 Score: 23
# Run [1660] - Total reward: 10830.00 Mean scores: 21.53 Means Scores[:-10]: 22.40 Score: 23
# Run [1670] - Total reward: 9820.00 Mean scores: 21.53 Means Scores[:-10]: 21.60 Score: 21
# Run [1680] - Total reward: 9760.00 Mean scores: 21.53 Means Scores[:-10]: 21.20 Score: 21
# Run [1690] - Total reward: 9770.00 Mean scores: 21.53 Means Scores[:-10]: 21.40 Score: 21
# Run [1700] - Total reward: 10970.00 Mean scores: 21.53 Means Scores[:-10]: 21.60 Score: 23
# Run [1710] - Total reward: 9840.00 Mean scores: 21.53 Means Scores[:-10]: 21.40 Score: 21
# Run [1720] - Total reward: 10860.00 Mean scores: 21.53 Means Scores[:-10]: 21.40 Score: 23
# Run [1730] - Total reward: 9770.00 Mean scores: 21.53 Means Scores[:-10]: 21.20 Score: 21
# Run [1740] - Total reward: 9860.00 Mean scores: 21.53 Means Scores[:-10]: 21.40 Score: 21
# Run [1750] - Total reward: 9760.00 Mean scores: 21.52 Means Scores[:-10]: 21.20 Score: 21
# Run [1760] - Total reward: 9780.00 Mean scores: 21.52 Means Scores[:-10]: 21.20 Score: 21
# Run [1770] - Total reward: 9810.00 Mean scores: 21.53 Means Scores[:-10]: 22.30 Score: 21
# Run [1780] - Total reward: 9810.00 Mean scores: 21.53 Means Scores[:-10]: 21.40 Score: 21
# Run [1790] - Total reward: 9720.00 Mean scores: 21.52 Means Scores[:-10]: 21.40 Score: 21
# Run [1800] - Total reward: 10860.00 Mean scores: 21.53 Means Scores[:-10]: 22.00 Score: 23
# Run [1810] - Total reward: 10820.00 Mean scores: 21.53 Means Scores[:-10]: 21.60 Score: 23
# Run [1820] - Total reward: 9700.00 Mean scores: 21.53 Means Scores[:-10]: 21.80 Score: 21
# Run [1830] - Total reward: 10810.00 Mean scores: 21.53 Means Scores[:-10]: 21.40 Score: 23
# Run [1840] - Total reward: 9760.00 Mean scores: 21.53 Means Scores[:-10]: 21.20 Score: 21
# Run [1850] - Total reward: 9770.00 Mean scores: 21.53 Means Scores[:-10]: 21.20 Score: 21
# Run [1860] - Total reward: 9810.00 Mean scores: 21.52 Means Scores[:-10]: 21.40 Score: 21
# Run [1870] - Total reward: 9920.00 Mean scores: 21.52 Means Scores[:-10]: 21.20 Score: 21
# Run [1880] - Total reward: 9830.00 Mean scores: 21.52 Means Scores[:-10]: 21.40 Score: 21
# Run [1890] - Total reward: 10830.00 Mean scores: 21.52 Means Scores[:-10]: 21.80 Score: 23
# Run [1900] - Total reward: 9810.00 Mean scores: 21.52 Means Scores[:-10]: 21.20 Score: 21
# Run [1910] - Total reward: 9740.00 Mean scores: 21.52 Means Scores[:-10]: 21.60 Score: 21
# Run [1920] - Total reward: 9810.00 Mean scores: 21.52 Means Scores[:-10]: 21.60 Score: 21
# Run [1930] - Total reward: 9850.00 Mean scores: 21.52 Means Scores[:-10]: 21.60 Score: 21
# Run [1940] - Total reward: 9780.00 Mean scores: 21.52 Means Scores[:-10]: 21.20 Score: 21
# Run [1950] - Total reward: 9770.00 Mean scores: 21.52 Means Scores[:-10]: 21.40 Score: 21
# Run [1960] - Total reward: 10830.00 Mean scores: 21.52 Means Scores[:-10]: 21.60 Score: 23
# Run [1970] - Total reward: 9830.00 Mean scores: 21.52 Means Scores[:-10]: 21.20 Score: 21
# Run [1980] - Total reward: 9790.00 Mean scores: 21.52 Means Scores[:-10]: 21.80 Score: 21
# Run [1990] - Total reward: 9830.00 Mean scores: 21.52 Means Scores[:-10]: 21.20 Score: 21
# Run [2000] - Total reward: 9710.00 Mean scores: 21.52 Means Scores[:-10]: 21.40 Score: 21
# Run [2010] - Total reward: 10900.00 Mean scores: 21.52 Means Scores[:-10]: 21.60 Score: 23
# Run [2020] - Total reward: 10830.00 Mean scores: 21.52 Means Scores[:-10]: 21.80 Score: 23
# Run [2030] - Total reward: 10820.00 Mean scores: 21.52 Means Scores[:-10]: 21.60 Score: 23
# Run [2040] - Total reward: 9760.00 Mean scores: 21.52 Means Scores[:-10]: 21.40 Score: 21
# Run [2050] - Total reward: 9790.00 Mean scores: 21.52 Means Scores[:-10]: 21.40 Score: 21
# Run [2060] - Total reward: 9820.00 Mean scores: 21.52 Means Scores[:-10]: 21.60 Score: 21
# Run [2070] - Total reward: 9830.00 Mean scores: 21.52 Means Scores[:-10]: 22.00 Score: 21
# Run [2080] - Total reward: 10830.00 Mean scores: 21.52 Means Scores[:-10]: 21.80 Score: 23
# Run [2090] - Total reward: 10840.00 Mean scores: 21.52 Means Scores[:-10]: 21.60 Score: 23
# Run [2100] - Total reward: 9830.00 Mean scores: 21.52 Means Scores[:-10]: 21.60 Score: 21
# Run [2110] - Total reward: 9780.00 Mean scores: 21.52 Means Scores[:-10]: 21.40 Score: 21
# Run [2120] - Total reward: 9810.00 Mean scores: 21.52 Means Scores[:-10]: 21.00 Score: 21
# Run [2130] - Total reward: 9800.00 Mean scores: 21.52 Means Scores[:-10]: 21.20 Score: 21
# Run [2140] - Total reward: 9800.00 Mean scores: 21.52 Means Scores[:-10]: 21.20 Score: 21
# Run [2150] - Total reward: 9760.00 Mean scores: 21.52 Means Scores[:-10]: 21.40 Score: 21
# Run [2160] - Total reward: 9740.00 Mean scores: 21.52 Means Scores[:-10]: 21.80 Score: 21
# Run [2170] - Total reward: 10850.00 Mean scores: 21.52 Means Scores[:-10]: 21.40 Score: 23
# Run [2180] - Total reward: 9750.00 Mean scores: 21.52 Means Scores[:-10]: 21.60 Score: 21
# Run [2190] - Total reward: 10800.00 Mean scores: 21.52 Means Scores[:-10]: 21.60 Score: 23
# Run [2200] - Total reward: 11954.00 Mean scores: 21.52 Means Scores[:-10]: 21.60 Score: 25
# Run [2210] - Total reward: 10770.00 Mean scores: 21.52 Means Scores[:-10]: 21.40 Score: 23
# Run [2220] - Total reward: 9790.00 Mean scores: 21.52 Means Scores[:-10]: 21.40 Score: 21
# Run [2230] - Total reward: 9750.00 Mean scores: 21.52 Means Scores[:-10]: 21.60 Score: 21
# Run [2240] - Total reward: 9800.00 Mean scores: 21.52 Means Scores[:-10]: 21.60 Score: 21
# Run [2250] - Total reward: 9830.00 Mean scores: 21.52 Means Scores[:-10]: 21.40 Score: 21
# Run [2260] - Total reward: 10770.00 Mean scores: 21.52 Means Scores[:-10]: 22.00 Score: 23
# Run [2270] - Total reward: 9740.00 Mean scores: 21.52 Means Scores[:-10]: 21.20 Score: 21
# Run [2280] - Total reward: 9820.00 Mean scores: 21.52 Means Scores[:-10]: 21.20 Score: 21
# Run [2290] - Total reward: 10880.00 Mean scores: 21.52 Means Scores[:-10]: 21.60 Score: 23
# Run [2300] - Total reward: 9800.00 Mean scores: 21.52 Means Scores[:-10]: 21.40 Score: 21
# Run [2310] - Total reward: 9820.00 Mean scores: 21.52 Means Scores[:-10]: 21.20 Score: 21
# Run [2320] - Total reward: 10830.00 Mean scores: 21.52 Means Scores[:-10]: 21.40 Score: 23
# Run [2330] - Total reward: 9840.00 Mean scores: 21.52 Means Scores[:-10]: 21.40 Score: 21
# Run [2340] - Total reward: 9790.00 Mean scores: 21.52 Means Scores[:-10]: 21.60 Score: 21
# Run [2350] - Total reward: 9740.00 Mean scores: 21.51 Means Scores[:-10]: 21.20 Score: 21
# Run [2360] - Total reward: 9819.00 Mean scores: 21.51 Means Scores[:-10]: 21.40 Score: 21
# Run [2370] - Total reward: 9830.00 Mean scores: 21.51 Means Scores[:-10]: 21.40 Score: 21
# Run [2380] - Total reward: 9700.00 Mean scores: 21.51 Means Scores[:-10]: 21.60 Score: 21
# Run [2390] - Total reward: 9800.00 Mean scores: 21.51 Means Scores[:-10]: 21.60 Score: 21
# Run [2400] - Total reward: 9740.00 Mean scores: 21.51 Means Scores[:-10]: 21.50 Score: 21
# Run [2410] - Total reward: 9790.00 Mean scores: 21.51 Means Scores[:-10]: 21.00 Score: 21
# Run [2420] - Total reward: 9820.00 Mean scores: 21.51 Means Scores[:-10]: 21.80 Score: 21
# Run [2430] - Total reward: 9720.00 Mean scores: 21.51 Means Scores[:-10]: 21.40 Score: 21
# Run [2440] - Total reward: 9810.00 Mean scores: 21.51 Means Scores[:-10]: 21.80 Score: 21
# Run [2450] - Total reward: 10790.00 Mean scores: 21.52 Means Scores[:-10]: 21.80 Score: 23
# Run [2460] - Total reward: 10860.00 Mean scores: 21.52 Means Scores[:-10]: 21.60 Score: 23
# Run [2470] - Total reward: 10900.00 Mean scores: 21.52 Means Scores[:-10]: 21.40 Score: 23
# Run [2480] - Total reward: 10870.00 Mean scores: 21.52 Means Scores[:-10]: 21.60 Score: 23
# Run [2490] - Total reward: 10810.00 Mean scores: 21.52 Means Scores[:-10]: 21.60 Score: 23
# CPU times: user 2h 1min 46s, sys: 9.16 s, total: 2h 1min 56s
# Wall time: 2h 3min 41s
